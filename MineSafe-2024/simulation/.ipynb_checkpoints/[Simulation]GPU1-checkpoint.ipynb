# %% [markdown]
# - Before move on, please run `install.sh` first.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os
import gc
import time
import numpy as np
import pandas as pd
import tensorflow as tf
# tf.debugging.set_log_device_placement(True)

# %matplotlib inline
from keras.preprocessing.image import array_to_img
import copy
import seaborn as sns
import cv2 as cv
import pickle
import tensorflow_probability as tfp
from tensorflow.keras.layers import AveragePooling2D
import shutil
import sys 

sys.path.append("../models/GPA")
sys.path.append("../")
from gpa import GPA
from utils import *
from simu_auxiliary import *

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1 Physical GPUs, 1 Logical GPUs
# 2024-05-04 03:22:46.278195: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-04 03:22:47.060549: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b3:00.0, compute capability: 6.0

# %%
def MSE(x, y):
    mse = tf.reduce_mean((x - y)**2)
    return mse

def MSE_median(x, y):
    mse = np.median((x - y)**2)
    return mse

# %%
T = 100                    # number of replications
N_list = [100, 500, 1000]  # number of images
p = 540
q = 960
G = 500

print(f"total replications T: {T}")
print(f"total sample size_list N_list:{N_list}")
print(f"image size p*q: {p}*{q}")
print(f"number of ticks on x axis G: {G}")
# Out:
# total replications T: 100
# total sample size_list N_list:[100, 500, 1000]
# image size p*q: 540*960
# number of ticks on x axis G: 500

# %%
avg_pool_2d_mean = AveragePooling2D(pool_size=(5, 5), strides=1, padding="same")
# the mean image
mean = np.load('./mean-540.npy')
mean = mean.reshape([1, p, q, 1])
mean = avg_pool_2d_mean(mean)
mean = tf.reshape(mean, (1, p, q))

show_img_one_channel(mean[0])
mean.shape
# Out:
# 2024-05-04 03:22:47.613548: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# TensorShape([1, 540, 960])

# %%
sigma = 0.2
test_size = 100

# %%
tick_list = np.random.uniform(size=G)
tick_tensor = tf.concat([tf.ones([1, p, q]) * tick for tick in tick_list], axis=0)

# %%
# true density
f_true = compute_true_density(tick_list, mean, sigma)

# location_weight
truncate_width = 3

tfd = tfp.distributions
dist = tfd.TruncatedNormal(loc=mean, scale=sigma, low=[0.], high=[1.])
# Out:
# True density shape: (500, 540, 960)

# %%
M = p * q

# %%
N = 1000
alpha = np.log(p*q) / np.log(N)
bandwidth, bandwidth_star = compute_optimal_bandwidths(N, M, sigma)
print(f"1/q / bandwidth:{1/q / bandwidth:.6f}")

N, bandwidth, bandwidth_star
# Out:
# Optimal bandwidth from Rule of Thumb: 0.015302491923891564
# Optimal bandwidth* from GPA estimation: 0.0011708312954038327
# 1/q / bandwidth:0.068072
# (1000, 0.015302491923891564, 0.0011708312954038327)

# %%
# N = 1000
# alpha = np.log(p*q) / np.log(N)
# bandwidth, bandwidth_star = compute_optimal_bandwidths(N, M, sigma)
# print(f"1/q / bandwidth:{1/q / bandwidth:.6f}")

# N, bandwidth, bandwidth_star

# %%
experiment_stats = {"N": [],
                    "t": [],
                    "CD_mse": [],
                    "DS_mse": [],
                    "GPA_CD_mse": [],
                    "GPA_DS_mse": [],
                    "DS_mse": [],
                    "CD_time": [],
                    "DS_time": [],
                    "GPA_CD_time": [],
                    "GPA_DS_time": []}

# %%
N_list = [100]

# %%
for N in N_list:
    print(f"============= N:{N} =============")
    alpha = np.log(p * q) / np.log(N)  # alpha
    path = f'../../simulate_img_N={N}_GPU1'  # path to save N simulate image

    # optimal bandwidth
    bandwidth, bandwidth_star = compute_optimal_bandwidths(N, M, sigma)
    location_weight_tensor = compute_location_weight(p, q, bandwidth, truncate_width)
    location_weight_tensor = tf.reshape(location_weight_tensor, [truncate_width, truncate_width, 1, 1])
    location_weight_tensor = tf.cast(location_weight_tensor, tf.float32)

    for t in range(T): # repliacte
        print(f"============= The {t}th replication with N samlpes:{N} =============")
        seed = N + t
        tf.random.set_seed(seed) # set random seed in one replication of N
        np.random.seed(seed)
        CD_mse = 0
        DS_mse = 0
        GPA_CD_mse = 0
        GPA_DS_mse = 0
        CD_time = 0
        DS_time = 0
        GPA_CD_time = 0
        GPA_DS_time = 0
        
        # generate N generated N simulation images
        generate_simulate_data(path, N, mean, sigma)
        
        # pre-computed CD and DS matrix
        CD_matrix = compute_CD_matrix(path, N, G, p, q, bandwidth, tick_tensor)
        DS_matrix = compute_DS_matrix(CD_matrix, location_weight_tensor)
        CD_matrix = tf.squeeze(CD_matrix)
        DS_matrix = tf.squeeze(DS_matrix)
        
        # density comparison
        for test_i in range(test_size): # 生成测试图片
            print(f"[TEST] image No.{test_i}")
            test_img = tf.ones([p, q]) * np.random.uniform()
            oracle_test = tf.squeeze(dist.prob(test_img))
            
            # CD estimation
            print(f"[TEST] compute CD estimator")
            t1 = time.time()
            CD_test = test_CD(p, q, test_img, bandwidth, path)
            CD_test = tf.reshape(CD_test, (1, p, q))
            t2 = time.time()
            CD_time += (t2 - t1) / test_size
            
            # DS estimation
            print(f"[TEST] compute DS estimator")
            t3 = time.time()
            DS_test = compute_DS_matrix(CD_test, location_weight_tensor)
            t4 = time.time()
            DS_time += (t4 - t3 + t2 - t1) / test_size
            
            # GPA-CD estimation
            print(f"[TEST] compute GPA-CD estimator")
            t1 = time.time()
            Omega2_star = K_tf(tick_tensor - test_img, bandwidth_star)
            Omega1_star = Omega2_star * CD_matrix
            Omega1_star = tf.reduce_sum(Omega1_star, axis=0)
            Omega2_star = tf.reduce_sum(Omega2_star, axis=0)
            GPA_CD_test = Omega1_star / Omega2_star
            t2 = time.time()
            GPA_CD_time += (t2 - t1) / test_size
            
            # GPA-DS estimation
            print(f"[TEST] compute GPA-DS estimator")
            t1 = time.time()
            Omega2_star = K_tf(tick_tensor - test_img, bandwidth_star)
            Omega1_star = Omega2_star * DS_matrix
            Omega1_star = tf.reduce_sum(Omega1_star, axis=0)
            Omega2_star = tf.reduce_sum(Omega2_star, axis=0)
            GPA_DS_test = Omega1_star / Omega2_star
            t2 = time.time()
            GPA_DS_time += (t2 - t1) / test_size

            ###################### Compute MSE ####################
            # 1. MSE of the CD estimator
            CD_test = tf.squeeze(CD_test)
            CD_mse += MSE(oracle_test, CD_test) / test_size
            # 2. MSE of the DS estimator
            DS_test = tf.squeeze(DS_test)
            DS_mse += MSE(oracle_test, DS_test) / test_size
            # 3. MSE of the GPA-CD estimator
            GPA_CD_test = tf.squeeze(GPA_CD_test)
            GPA_CD_mse += MSE(oracle_test, GPA_CD_test) / test_size
            # 4. MSE of the GPA-DS estimator
            GPA_DS_test = tf.squeeze(GPA_DS_test)
            GPA_DS_mse += MSE(oracle_test, GPA_DS_test) / test_size
            print(f"Sample size N:{N}")
            print(f"CD MSE: {CD_mse.numpy():.8f}")
            print(f"DS MSE: {DS_mse.numpy():.8f}")
            print(f"GPA_CD MSE: {GPA_CD_mse.numpy():.8f}")
            print(f"GPA_DS MSE: {GPA_DS_mse.numpy():.8f}")
        
        experiment_stats["N"].append(N)
        experiment_stats["t"].append(t)
        experiment_stats["CD_mse"].append(CD_mse.numpy())
        experiment_stats["DS_mse"].append(DS_mse.numpy())
        experiment_stats["GPA_CD_mse"].append(GPA_CD_mse.numpy())
        experiment_stats["GPA_DS_mse"].append(GPA_DS_mse.numpy())
        experiment_stats["CD_time"].append(CD_time)
        experiment_stats["DS_time"].append(DS_time)
        experiment_stats["GPA_CD_time"].append(GPA_CD_time)
        experiment_stats["GPA_DS_time"].append(GPA_DS_time)
        experiment_stats_csv = pd.DataFrame(experiment_stats)
        experiment_stats_csv.to_csv(f'./simulation(N={N}).csv')
# Out:
# ============= N:100 =============
# Optimal bandwidth from Rule of Thumb: 0.021262743580928653
# Optimal bandwidth* from GPA estimation: 0.0022605213229416133
# ============= The 0th replication with N samlpes:100 =============
# -[CD] Successfully compute classical density with N=100 at ../../simulate_img_N=100_GPU1
# [TEST] image No.0
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00165375
# DS MSE: 0.00020553
# GPA_CD MSE: 0.00165044
# GPA_DS MSE: 0.00020516
# [TEST] image No.1
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00329347
# DS MSE: 0.00042604
# GPA_CD MSE: 0.00328031
# GPA_DS MSE: 0.00042484
# [TEST] image No.2
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00514994
# DS MSE: 0.00066360
# GPA_CD MSE: 0.00512759
# GPA_DS MSE: 0.00066148
# [TEST] image No.3
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00573596
# DS MSE: 0.00074385
# GPA_CD MSE: 0.00570494
# GPA_DS MSE: 0.00074085
# [TEST] image No.4
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00672421
# DS MSE: 0.00144230
# GPA_CD MSE: 0.00672218
# GPA_DS MSE: 0.00147680
# [TEST] image No.5
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00771927
# DS MSE: 0.00158199
# GPA_CD MSE: 0.00771505
# GPA_DS MSE: 0.00161625
# [TEST] image No.6
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00891057
# DS MSE: 0.00173125
# GPA_CD MSE: 0.00889350
# GPA_DS MSE: 0.00176411
# [TEST] image No.7
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00955013
# DS MSE: 0.00181799
# GPA_CD MSE: 0.00952826
# GPA_DS MSE: 0.00185032
# [TEST] image No.8
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01060995
# DS MSE: 0.00196563
# GPA_CD MSE: 0.01058565
# GPA_DS MSE: 0.00199768
# [TEST] image No.9
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01215681
# DS MSE: 0.00215866
# GPA_CD MSE: 0.01212394
# GPA_DS MSE: 0.00218992
# [TEST] image No.10
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01262091
# DS MSE: 0.00222335
# GPA_CD MSE: 0.01258580
# GPA_DS MSE: 0.00225437
# [TEST] image No.11
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01399567
# DS MSE: 0.00241010
# GPA_CD MSE: 0.01395476
# GPA_DS MSE: 0.00244048
# [TEST] image No.12
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01527199
# DS MSE: 0.00258575
# GPA_CD MSE: 0.01522234
# GPA_DS MSE: 0.00261531
# [TEST] image No.13
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01620933
# DS MSE: 0.00271798
# GPA_CD MSE: 0.01615806
# GPA_DS MSE: 0.00274735
# [TEST] image No.14
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01762493
# DS MSE: 0.00290933
# GPA_CD MSE: 0.01756169
# GPA_DS MSE: 0.00293743
# [TEST] image No.15
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01798806
# DS MSE: 0.00303529
# GPA_CD MSE: 0.01792942
# GPA_DS MSE: 0.00307062
# [TEST] image No.16
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01867023
# DS MSE: 0.00312688
# GPA_CD MSE: 0.01861062
# GPA_DS MSE: 0.00316228
# [TEST] image No.17
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01988623
# DS MSE: 0.00329513
# GPA_CD MSE: 0.01982228
# GPA_DS MSE: 0.00333016
# [TEST] image No.18
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02055449
# DS MSE: 0.00338514
# GPA_CD MSE: 0.02048379
# GPA_DS MSE: 0.00341946
# [TEST] image No.19
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02218199
# DS MSE: 0.00360451
# GPA_CD MSE: 0.02210589
# GPA_DS MSE: 0.00363831
# [TEST] image No.20
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02403228
# DS MSE: 0.00384084
# GPA_CD MSE: 0.02391663
# GPA_DS MSE: 0.00387073
# [TEST] image No.21
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02439357
# DS MSE: 0.00389229
# GPA_CD MSE: 0.02427657
# GPA_DS MSE: 0.00392202
# [TEST] image No.22
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02505752
# DS MSE: 0.00398182
# GPA_CD MSE: 0.02493460
# GPA_DS MSE: 0.00401090
# [TEST] image No.23
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02685167
# DS MSE: 0.00421764
# GPA_CD MSE: 0.02671939
# GPA_DS MSE: 0.00424579
# [TEST] image No.24
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02808359
# DS MSE: 0.00438791
# GPA_CD MSE: 0.02794809
# GPA_DS MSE: 0.00441570
# [TEST] image No.25
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02992066
# DS MSE: 0.00462713
# GPA_CD MSE: 0.02977343
# GPA_DS MSE: 0.00465363
# [TEST] image No.26
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03087276
# DS MSE: 0.00527647
# GPA_CD MSE: 0.03077182
# GPA_DS MSE: 0.00536264
# [TEST] image No.27
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03242520
# DS MSE: 0.00548723
# GPA_CD MSE: 0.03231522
# GPA_DS MSE: 0.00557244
# [TEST] image No.28
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03315797
# DS MSE: 0.00558475
# GPA_CD MSE: 0.03304779
# GPA_DS MSE: 0.00566999
# [TEST] image No.29
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03387166
# DS MSE: 0.00588272
# GPA_CD MSE: 0.03372577
# GPA_DS MSE: 0.00591737
# [TEST] image No.30
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03533467
# DS MSE: 0.00606432
# GPA_CD MSE: 0.03517301
# GPA_DS MSE: 0.00609724
# [TEST] image No.31
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03677997
# DS MSE: 0.00624353
# GPA_CD MSE: 0.03659464
# GPA_DS MSE: 0.00627434
# [TEST] image No.32
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03770335
# DS MSE: 0.00637390
# GPA_CD MSE: 0.03752309
# GPA_DS MSE: 0.00640562
# [TEST] image No.33
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03954888
# DS MSE: 0.00661352
# GPA_CD MSE: 0.03936292
# GPA_DS MSE: 0.00664480
# [TEST] image No.34
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04019900
# DS MSE: 0.00671603
# GPA_CD MSE: 0.04000971
# GPA_DS MSE: 0.00674489
# [TEST] image No.35
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04066525
# DS MSE: 0.00678098
# GPA_CD MSE: 0.04047271
# GPA_DS MSE: 0.00680949
# [TEST] image No.36
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04104954
# DS MSE: 0.00693657
# GPA_CD MSE: 0.04085200
# GPA_DS MSE: 0.00696014
# [TEST] image No.37
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04178523
# DS MSE: 0.00704219
# GPA_CD MSE: 0.04158349
# GPA_DS MSE: 0.00706533
# [TEST] image No.38
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04225117
# DS MSE: 0.00710710
# GPA_CD MSE: 0.04204630
# GPA_DS MSE: 0.00712990
# [TEST] image No.39
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04379147
# DS MSE: 0.00729927
# GPA_CD MSE: 0.04357266
# GPA_DS MSE: 0.00732054
# [TEST] image No.40
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04470893
# DS MSE: 0.00741829
# GPA_CD MSE: 0.04448811
# GPA_DS MSE: 0.00743954
# [TEST] image No.41
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04605603
# DS MSE: 0.00758563
# GPA_CD MSE: 0.04582874
# GPA_DS MSE: 0.00760617
# [TEST] image No.42
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04757861
# DS MSE: 0.00777544
# GPA_CD MSE: 0.04734343
# GPA_DS MSE: 0.00779512
# [TEST] image No.43
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04823782
# DS MSE: 0.00797326
# GPA_CD MSE: 0.04799286
# GPA_DS MSE: 0.00798200
# [TEST] image No.44
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04961580
# DS MSE: 0.00816036
# GPA_CD MSE: 0.04936324
# GPA_DS MSE: 0.00816827
# [TEST] image No.45
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05126576
# DS MSE: 0.00836543
# GPA_CD MSE: 0.05101160
# GPA_DS MSE: 0.00837331
# [TEST] image No.46
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05208689
# DS MSE: 0.00847346
# GPA_CD MSE: 0.05182574
# GPA_DS MSE: 0.00848060
# [TEST] image No.47
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05363227
# DS MSE: 0.00868326
# GPA_CD MSE: 0.05336432
# GPA_DS MSE: 0.00868966
# [TEST] image No.48
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05529262
# DS MSE: 0.00890564
# GPA_CD MSE: 0.05501014
# GPA_DS MSE: 0.00891047
# [TEST] image No.49
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05585779
# DS MSE: 0.00898323
# GPA_CD MSE: 0.05557260
# GPA_DS MSE: 0.00898782
# [TEST] image No.50
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05619919
# DS MSE: 0.00907619
# GPA_CD MSE: 0.05590707
# GPA_DS MSE: 0.00907416
# [TEST] image No.51
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05667884
# DS MSE: 0.00914274
# GPA_CD MSE: 0.05638305
# GPA_DS MSE: 0.00914033
# [TEST] image No.52
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05850314
# DS MSE: 0.00938123
# GPA_CD MSE: 0.05820296
# GPA_DS MSE: 0.00937839
# [TEST] image No.53
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05996609
# DS MSE: 0.00956282
# GPA_CD MSE: 0.05965023
# GPA_DS MSE: 0.00955827
# [TEST] image No.54
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06178553
# DS MSE: 0.00980093
# GPA_CD MSE: 0.06143517
# GPA_DS MSE: 0.00979339
# [TEST] image No.55
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06358634
# DS MSE: 0.01003735
# GPA_CD MSE: 0.06322391
# GPA_DS MSE: 0.01002847
# [TEST] image No.56
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06483041
# DS MSE: 0.01020912
# GPA_CD MSE: 0.06445775
# GPA_DS MSE: 0.01019933
# [TEST] image No.57
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06632023
# DS MSE: 0.01041070
# GPA_CD MSE: 0.06594012
# GPA_DS MSE: 0.01040021
# [TEST] image No.58
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06699806
# DS MSE: 0.01051027
# GPA_CD MSE: 0.06661095
# GPA_DS MSE: 0.01049831
# [TEST] image No.59
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06875519
# DS MSE: 0.01073072
# GPA_CD MSE: 0.06835429
# GPA_DS MSE: 0.01071732
# [TEST] image No.60
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07059546
# DS MSE: 0.01097009
# GPA_CD MSE: 0.07017724
# GPA_DS MSE: 0.01095524
# [TEST] image No.61
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07207964
# DS MSE: 0.01115461
# GPA_CD MSE: 0.07165428
# GPA_DS MSE: 0.01113900
# [TEST] image No.62
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07342765
# DS MSE: 0.01132205
# GPA_CD MSE: 0.07299545
# GPA_DS MSE: 0.01130570
# [TEST] image No.63
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07451237
# DS MSE: 0.01147280
# GPA_CD MSE: 0.07407041
# GPA_DS MSE: 0.01145539
# [TEST] image No.64
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07488503
# DS MSE: 0.01152564
# GPA_CD MSE: 0.07444052
# GPA_DS MSE: 0.01150795
# [TEST] image No.65
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07523513
# DS MSE: 0.01157583
# GPA_CD MSE: 0.07478924
# GPA_DS MSE: 0.01155793
# [TEST] image No.66
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07668585
# DS MSE: 0.01175577
# GPA_CD MSE: 0.07622690
# GPA_DS MSE: 0.01173645
# [TEST] image No.67
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07853654
# DS MSE: 0.01199561
# GPA_CD MSE: 0.07806162
# GPA_DS MSE: 0.01197484
# [TEST] image No.68
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08036447
# DS MSE: 0.01223434
# GPA_CD MSE: 0.07987282
# GPA_DS MSE: 0.01221187
# [TEST] image No.69
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08172006
# DS MSE: 0.01241899
# GPA_CD MSE: 0.08122180
# GPA_DS MSE: 0.01239608
# [TEST] image No.70
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08335528
# DS MSE: 0.01263909
# GPA_CD MSE: 0.08284971
# GPA_DS MSE: 0.01261542
# [TEST] image No.71
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08488322
# DS MSE: 0.01284639
# GPA_CD MSE: 0.08436447
# GPA_DS MSE: 0.01282139
# [TEST] image No.72
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08610688
# DS MSE: 0.01301562
# GPA_CD MSE: 0.08558614
# GPA_DS MSE: 0.01299048
# [TEST] image No.73
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08643243
# DS MSE: 0.01307363
# GPA_CD MSE: 0.08590964
# GPA_DS MSE: 0.01304857
# [TEST] image No.74
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08676564
# DS MSE: 0.01312330
# GPA_CD MSE: 0.08624101
# GPA_DS MSE: 0.01309801
# [TEST] image No.75
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08823172
# DS MSE: 0.01330532
# GPA_CD MSE: 0.08769139
# GPA_DS MSE: 0.01327850
# [TEST] image No.76
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08918974
# DS MSE: 0.01342897
# GPA_CD MSE: 0.08864050
# GPA_DS MSE: 0.01340115
# [TEST] image No.77
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09099086
# DS MSE: 0.01366541
# GPA_CD MSE: 0.09042983
# GPA_DS MSE: 0.01363628
# [TEST] image No.78
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09185861
# DS MSE: 0.01378845
# GPA_CD MSE: 0.09127326
# GPA_DS MSE: 0.01375947
# [TEST] image No.79
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09367996
# DS MSE: 0.01402003
# GPA_CD MSE: 0.09308457
# GPA_DS MSE: 0.01398993
# [TEST] image No.80
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09542927
# DS MSE: 0.01423934
# GPA_CD MSE: 0.09482367
# GPA_DS MSE: 0.01420810
# [TEST] image No.81
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09628190
# DS MSE: 0.01436041
# GPA_CD MSE: 0.09567080
# GPA_DS MSE: 0.01432903
# [TEST] image No.82
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09797988
# DS MSE: 0.01457204
# GPA_CD MSE: 0.09733398
# GPA_DS MSE: 0.01453687
# [TEST] image No.83
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09859292
# DS MSE: 0.01501481
# GPA_CD MSE: 0.09796873
# GPA_DS MSE: 0.01500559
# [TEST] image No.84
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10044925
# DS MSE: 0.01525484
# GPA_CD MSE: 0.09981354
# GPA_DS MSE: 0.01524436
# [TEST] image No.85
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10224249
# DS MSE: 0.01549058
# GPA_CD MSE: 0.10159510
# GPA_DS MSE: 0.01547893
# [TEST] image No.86
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10294408
# DS MSE: 0.01558441
# GPA_CD MSE: 0.10229323
# GPA_DS MSE: 0.01557239
# [TEST] image No.87
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10381803
# DS MSE: 0.01569853
# GPA_CD MSE: 0.10316983
# GPA_DS MSE: 0.01568756
# [TEST] image No.88
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10555793
# DS MSE: 0.01592920
# GPA_CD MSE: 0.10490307
# GPA_DS MSE: 0.01591797
# [TEST] image No.89
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10689051
# DS MSE: 0.01609492
# GPA_CD MSE: 0.10622450
# GPA_DS MSE: 0.01608247
# [TEST] image No.90
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10855304
# DS MSE: 0.01630155
# GPA_CD MSE: 0.10787436
# GPA_DS MSE: 0.01628789
# [TEST] image No.91
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11024418
# DS MSE: 0.01652692
# GPA_CD MSE: 0.10955328
# GPA_DS MSE: 0.01651192
# [TEST] image No.92
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11119203
# DS MSE: 0.01666054
# GPA_CD MSE: 0.11049229
# GPA_DS MSE: 0.01664498
# [TEST] image No.93
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11293069
# DS MSE: 0.01689108
# GPA_CD MSE: 0.11222493
# GPA_DS MSE: 0.01687535
# [TEST] image No.94
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11475649
# DS MSE: 0.01712353
# GPA_CD MSE: 0.11403241
# GPA_DS MSE: 0.01710575
# [TEST] image No.95
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11599436
# DS MSE: 0.01727816
# GPA_CD MSE: 0.11526130
# GPA_DS MSE: 0.01725940
# [TEST] image No.96
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11755413
# DS MSE: 0.01748991
# GPA_CD MSE: 0.11679813
# GPA_DS MSE: 0.01746864
# [TEST] image No.97
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11886009
# DS MSE: 0.01765260
# GPA_CD MSE: 0.11809775
# GPA_DS MSE: 0.01763063
# [TEST] image No.98
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.12019870
# DS MSE: 0.01783537
# GPA_CD MSE: 0.11942975
# GPA_DS MSE: 0.01781269
# [TEST] image No.99
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.12144168
# DS MSE: 0.01799060
# GPA_CD MSE: 0.12066423
# GPA_DS MSE: 0.01796702
# ============= The 1th replication with N samlpes:100 =============
# -[CD] Successfully compute classical density with N=100 at ../../simulate_img_N=100_GPU1
# [TEST] image No.0
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00171881
# DS MSE: 0.00021591
# GPA_CD MSE: 0.00169902
# GPA_DS MSE: 0.00021398
# [TEST] image No.1
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00329000
# DS MSE: 0.00041148
# GPA_CD MSE: 0.00326399
# GPA_DS MSE: 0.00040923
# [TEST] image No.2
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00392718
# DS MSE: 0.00053640
# GPA_CD MSE: 0.00390229
# GPA_DS MSE: 0.00054543
# [TEST] image No.3
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00514250
# DS MSE: 0.00070352
# GPA_CD MSE: 0.00511200
# GPA_DS MSE: 0.00071207
# [TEST] image No.4
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00627603
# DS MSE: 0.00084596
# GPA_CD MSE: 0.00624367
# GPA_DS MSE: 0.00085433
# [TEST] image No.5
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00689285
# DS MSE: 0.00092927
# GPA_CD MSE: 0.00685175
# GPA_DS MSE: 0.00093677
# [TEST] image No.6
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00861496
# DS MSE: 0.00115723
# GPA_CD MSE: 0.00855769
# GPA_DS MSE: 0.00116335
# [TEST] image No.7
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.00907600
# DS MSE: 0.00122140
# GPA_CD MSE: 0.00901792
# GPA_DS MSE: 0.00122749
# [TEST] image No.8
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01006832
# DS MSE: 0.00134827
# GPA_CD MSE: 0.01000232
# GPA_DS MSE: 0.00135356
# [TEST] image No.9
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01136705
# DS MSE: 0.00152586
# GPA_CD MSE: 0.01129417
# GPA_DS MSE: 0.00153072
# [TEST] image No.10
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01299023
# DS MSE: 0.00172743
# GPA_CD MSE: 0.01290523
# GPA_DS MSE: 0.00173094
# [TEST] image No.11
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01480512
# DS MSE: 0.00196709
# GPA_CD MSE: 0.01471242
# GPA_DS MSE: 0.00197007
# [TEST] image No.12
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01606826
# DS MSE: 0.00214016
# GPA_CD MSE: 0.01596775
# GPA_DS MSE: 0.00214231
# [TEST] image No.13
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01683430
# DS MSE: 0.00224073
# GPA_CD MSE: 0.01673012
# GPA_DS MSE: 0.00224258
# [TEST] image No.14
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01716032
# DS MSE: 0.00229757
# GPA_CD MSE: 0.01705404
# GPA_DS MSE: 0.00229880
# [TEST] image No.15
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01863352
# DS MSE: 0.00249674
# GPA_CD MSE: 0.01851789
# GPA_DS MSE: 0.00249695
# [TEST] image No.16
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.01946565
# DS MSE: 0.00261400
# GPA_CD MSE: 0.01935012
# GPA_DS MSE: 0.00261467
# [TEST] image No.17
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02091884
# DS MSE: 0.00279528
# GPA_CD MSE: 0.02077874
# GPA_DS MSE: 0.00279353
# [TEST] image No.18
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02188292
# DS MSE: 0.00291896
# GPA_CD MSE: 0.02173911
# GPA_DS MSE: 0.00291697
# [TEST] image No.19
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02350896
# DS MSE: 0.00313615
# GPA_CD MSE: 0.02335840
# GPA_DS MSE: 0.00313341
# [TEST] image No.20
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02464237
# DS MSE: 0.00327857
# GPA_CD MSE: 0.02449001
# GPA_DS MSE: 0.00327567
# [TEST] image No.21
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02635753
# DS MSE: 0.00349400
# GPA_CD MSE: 0.02619143
# GPA_DS MSE: 0.00349018
# [TEST] image No.22
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02704794
# DS MSE: 0.00359349
# GPA_CD MSE: 0.02688035
# GPA_DS MSE: 0.00358943
# [TEST] image No.23
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02811102
# DS MSE: 0.00374245
# GPA_CD MSE: 0.02793870
# GPA_DS MSE: 0.00373789
# [TEST] image No.24
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.02939682
# DS MSE: 0.00391840
# GPA_CD MSE: 0.02922584
# GPA_DS MSE: 0.00391422
# [TEST] image No.25
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03008571
# DS MSE: 0.00445124
# GPA_CD MSE: 0.02989704
# GPA_DS MSE: 0.00442751
# [TEST] image No.26
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03179395
# DS MSE: 0.00466573
# GPA_CD MSE: 0.03160113
# GPA_DS MSE: 0.00464155
# [TEST] image No.27
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03333680
# DS MSE: 0.00485814
# GPA_CD MSE: 0.03313413
# GPA_DS MSE: 0.00483291
# [TEST] image No.28
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03427924
# DS MSE: 0.00497932
# GPA_CD MSE: 0.03406812
# GPA_DS MSE: 0.00495321
# [TEST] image No.29
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03593538
# DS MSE: 0.00518575
# GPA_CD MSE: 0.03571735
# GPA_DS MSE: 0.00515897
# [TEST] image No.30
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03634984
# DS MSE: 0.00524372
# GPA_CD MSE: 0.03613341
# GPA_DS MSE: 0.00521722
# [TEST] image No.31
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03704275
# DS MSE: 0.00533564
# GPA_CD MSE: 0.03682086
# GPA_DS MSE: 0.00530852
# [TEST] image No.32
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.03890187
# DS MSE: 0.00557583
# GPA_CD MSE: 0.03867033
# GPA_DS MSE: 0.00554776
# [TEST] image No.33
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04072320
# DS MSE: 0.00581597
# GPA_CD MSE: 0.04049222
# GPA_DS MSE: 0.00578887
# [TEST] image No.34
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04106329
# DS MSE: 0.00586545
# GPA_CD MSE: 0.04083152
# GPA_DS MSE: 0.00583820
# [TEST] image No.35
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04286582
# DS MSE: 0.00610383
# GPA_CD MSE: 0.04262410
# GPA_DS MSE: 0.00607556
# [TEST] image No.36
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04339989
# DS MSE: 0.00617748
# GPA_CD MSE: 0.04315604
# GPA_DS MSE: 0.00614905
# [TEST] image No.37
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04402663
# DS MSE: 0.00626195
# GPA_CD MSE: 0.04378632
# GPA_DS MSE: 0.00623449
# [TEST] image No.38
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04569222
# DS MSE: 0.00646992
# GPA_CD MSE: 0.04543777
# GPA_DS MSE: 0.00644090
# [TEST] image No.39
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04608751
# DS MSE: 0.00652539
# GPA_CD MSE: 0.04582900
# GPA_DS MSE: 0.00649613
# [TEST] image No.40
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04697601
# DS MSE: 0.00665086
# GPA_CD MSE: 0.04672116
# GPA_DS MSE: 0.00662208
# [TEST] image No.41
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04788809
# DS MSE: 0.00677980
# GPA_CD MSE: 0.04763246
# GPA_DS MSE: 0.00675154
# [TEST] image No.42
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04895782
# DS MSE: 0.00691518
# GPA_CD MSE: 0.04869023
# GPA_DS MSE: 0.00688562
# [TEST] image No.43
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04942688
# DS MSE: 0.00698045
# GPA_CD MSE: 0.04915604
# GPA_DS MSE: 0.00695052
# [TEST] image No.44
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05058717
# DS MSE: 0.00714097
# GPA_CD MSE: 0.05031046
# GPA_DS MSE: 0.00711040
# [TEST] image No.45
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05221109
# DS MSE: 0.00735791
# GPA_CD MSE: 0.05192843
# GPA_DS MSE: 0.00732669
# [TEST] image No.46
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05339724
# DS MSE: 0.00750638
# GPA_CD MSE: 0.05310663
# GPA_DS MSE: 0.00747434
# [TEST] image No.47
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05457916
# DS MSE: 0.00766946
# GPA_CD MSE: 0.05427681
# GPA_DS MSE: 0.00763625
# [TEST] image No.48
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05564942
# DS MSE: 0.00780490
# GPA_CD MSE: 0.05533617
# GPA_DS MSE: 0.00777049
# [TEST] image No.49
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05743236
# DS MSE: 0.00802931
# GPA_CD MSE: 0.05711254
# GPA_DS MSE: 0.00799413
# [TEST] image No.50
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05858459
# DS MSE: 0.00817385
# GPA_CD MSE: 0.05824921
# GPA_DS MSE: 0.00813743
# [TEST] image No.51
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06029065
# DS MSE: 0.00838804
# GPA_CD MSE: 0.05995230
# GPA_DS MSE: 0.00835122
# [TEST] image No.52
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06096246
# DS MSE: 0.00848665
# GPA_CD MSE: 0.06061042
# GPA_DS MSE: 0.00845313
# [TEST] image No.53
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06240108
# DS MSE: 0.00868176
# GPA_CD MSE: 0.06203725
# GPA_DS MSE: 0.00864708
# [TEST] image No.54
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06395657
# DS MSE: 0.00887560
# GPA_CD MSE: 0.06358330
# GPA_DS MSE: 0.00883993
# [TEST] image No.55
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06494264
# DS MSE: 0.00901483
# GPA_CD MSE: 0.06456963
# GPA_DS MSE: 0.00897924
# [TEST] image No.56
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06670048
# DS MSE: 0.00923576
# GPA_CD MSE: 0.06632228
# GPA_DS MSE: 0.00919955
# [TEST] image No.57
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06776419
# DS MSE: 0.00938480
# GPA_CD MSE: 0.06738101
# GPA_DS MSE: 0.00934807
# [TEST] image No.58
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06847121
# DS MSE: 0.00948595
# GPA_CD MSE: 0.06808770
# GPA_DS MSE: 0.00944891
# [TEST] image No.59
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06971784
# DS MSE: 0.00965695
# GPA_CD MSE: 0.06932322
# GPA_DS MSE: 0.00961885
# [TEST] image No.60
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07156959
# DS MSE: 0.00989302
# GPA_CD MSE: 0.07114968
# GPA_DS MSE: 0.00985214
# [TEST] image No.61
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07207175
# DS MSE: 0.00996273
# GPA_CD MSE: 0.07164678
# GPA_DS MSE: 0.00992128
# [TEST] image No.62
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07241792
# DS MSE: 0.01001245
# GPA_CD MSE: 0.07198855
# GPA_DS MSE: 0.00997089
# [TEST] image No.63
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07421650
# DS MSE: 0.01023937
# GPA_CD MSE: 0.07377271
# GPA_DS MSE: 0.01019627
# [TEST] image No.64
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07604191
# DS MSE: 0.01047093
# GPA_CD MSE: 0.07558915
# GPA_DS MSE: 0.01042700
# [TEST] image No.65
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07736813
# DS MSE: 0.01063669
# GPA_CD MSE: 0.07690430
# GPA_DS MSE: 0.01059170
# [TEST] image No.66
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07913487
# DS MSE: 0.01087032
# GPA_CD MSE: 0.07863447
# GPA_DS MSE: 0.01082129
# [TEST] image No.67
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08010869
# DS MSE: 0.01100791
# GPA_CD MSE: 0.07960537
# GPA_DS MSE: 0.01095868
# [TEST] image No.68
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08080909
# DS MSE: 0.01110835
# GPA_CD MSE: 0.08030041
# GPA_DS MSE: 0.01105838
# [TEST] image No.69
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08213389
# DS MSE: 0.01127392
# GPA_CD MSE: 0.08161507
# GPA_DS MSE: 0.01122299
# [TEST] image No.70
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08281323
# DS MSE: 0.01136433
# GPA_CD MSE: 0.08229160
# GPA_DS MSE: 0.01131326
# [TEST] image No.71
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08400868
# DS MSE: 0.01151390
# GPA_CD MSE: 0.08347504
# GPA_DS MSE: 0.01146153
# [TEST] image No.72
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08527897
# DS MSE: 0.01167256
# GPA_CD MSE: 0.08474030
# GPA_DS MSE: 0.01161975
# [TEST] image No.73
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08714164
# DS MSE: 0.01191140
# GPA_CD MSE: 0.08659421
# GPA_DS MSE: 0.01185774
# [TEST] image No.74
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08839290
# DS MSE: 0.01206772
# GPA_CD MSE: 0.08783799
# GPA_DS MSE: 0.01201333
# [TEST] image No.75
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08977100
# DS MSE: 0.01225532
# GPA_CD MSE: 0.08921044
# GPA_DS MSE: 0.01220034
# [TEST] image No.76
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09100893
# DS MSE: 0.01241002
# GPA_CD MSE: 0.09043826
# GPA_DS MSE: 0.01235393
# [TEST] image No.77
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09269526
# DS MSE: 0.01262131
# GPA_CD MSE: 0.09210774
# GPA_DS MSE: 0.01256481
# [TEST] image No.78
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09358811
# DS MSE: 0.01273681
# GPA_CD MSE: 0.09299271
# GPA_DS MSE: 0.01267958
# [TEST] image No.79
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09446257
# DS MSE: 0.01286020
# GPA_CD MSE: 0.09385721
# GPA_DS MSE: 0.01280248
# [TEST] image No.80
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09523220
# DS MSE: 0.01296122
# GPA_CD MSE: 0.09462315
# GPA_DS MSE: 0.01290325
# [TEST] image No.81
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09635784
# DS MSE: 0.01310278
# GPA_CD MSE: 0.09574798
# GPA_DS MSE: 0.01304500
# [TEST] image No.82
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09745255
# DS MSE: 0.01324091
# GPA_CD MSE: 0.09683955
# GPA_DS MSE: 0.01318282
# [TEST] image No.83
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09921747
# DS MSE: 0.01346277
# GPA_CD MSE: 0.09859804
# GPA_DS MSE: 0.01340430
# [TEST] image No.84
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09956136
# DS MSE: 0.01356006
# GPA_CD MSE: 0.09893609
# GPA_DS MSE: 0.01349714
# [TEST] image No.85
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10091661
# DS MSE: 0.01374477
# GPA_CD MSE: 0.10027838
# GPA_DS MSE: 0.01368060
# [TEST] image No.86
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10261510
# DS MSE: 0.01397007
# GPA_CD MSE: 0.10196465
# GPA_DS MSE: 0.01390455
# [TEST] image No.87
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10406905
# DS MSE: 0.01416700
# GPA_CD MSE: 0.10341377
# GPA_DS MSE: 0.01410102
# [TEST] image No.88
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10475827
# DS MSE: 0.01426639
# GPA_CD MSE: 0.10410251
# GPA_DS MSE: 0.01420014
# [TEST] image No.89
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10519362
# DS MSE: 0.01432709
# GPA_CD MSE: 0.10453711
# GPA_DS MSE: 0.01426079
# [TEST] image No.90
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10601141
# DS MSE: 0.01444237
# GPA_CD MSE: 0.10534897
# GPA_DS MSE: 0.01437559
# [TEST] image No.91
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10745094
# DS MSE: 0.01462204
# GPA_CD MSE: 0.10678215
# GPA_DS MSE: 0.01455469
# [TEST] image No.92
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10880170
# DS MSE: 0.01479101
# GPA_CD MSE: 0.10812719
# GPA_DS MSE: 0.01472305
# [TEST] image No.93
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11064407
# DS MSE: 0.01503170
# GPA_CD MSE: 0.10996077
# GPA_DS MSE: 0.01496325
# [TEST] image No.94
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11139328
# DS MSE: 0.01538665
# GPA_CD MSE: 0.11063413
# GPA_DS MSE: 0.01521154
# [TEST] image No.95
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11198772
# DS MSE: 0.01546734
# GPA_CD MSE: 0.11123134
# GPA_DS MSE: 0.01529287
# [TEST] image No.96
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11383590
# DS MSE: 0.01570798
# GPA_CD MSE: 0.11307369
# GPA_DS MSE: 0.01553291
# [TEST] image No.97
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# ...
# CD MSE: 0.04185109
# DS MSE: 0.00568560
# GPA_CD MSE: 0.04162492
# GPA_DS MSE: 0.00565351
# [TEST] image No.34
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04242032
# DS MSE: 0.00576413
# GPA_CD MSE: 0.04219202
# GPA_DS MSE: 0.00573181
# [TEST] image No.35
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04424231
# DS MSE: 0.00599437
# GPA_CD MSE: 0.04400295
# GPA_DS MSE: 0.00596084
# [TEST] image No.36
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04577307
# DS MSE: 0.00618385
# GPA_CD MSE: 0.04552627
# GPA_DS MSE: 0.00614950
# [TEST] image No.37
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04610173
# DS MSE: 0.00624058
# GPA_CD MSE: 0.04585274
# GPA_DS MSE: 0.00620579
# [TEST] image No.38
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04775833
# DS MSE: 0.00646423
# GPA_CD MSE: 0.04749488
# GPA_DS MSE: 0.00642782
# [TEST] image No.39
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04827562
# DS MSE: 0.00653638
# GPA_CD MSE: 0.04800714
# GPA_DS MSE: 0.00649939
# [TEST] image No.40
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04910533
# DS MSE: 0.00665453
# GPA_CD MSE: 0.04883942
# GPA_DS MSE: 0.00661825
# [TEST] image No.41
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.04986953
# DS MSE: 0.00675583
# GPA_CD MSE: 0.04959979
# GPA_DS MSE: 0.00671918
# [TEST] image No.42
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05133826
# DS MSE: 0.00695569
# GPA_CD MSE: 0.05105937
# GPA_DS MSE: 0.00691803
# [TEST] image No.43
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05227306
# DS MSE: 0.00708811
# GPA_CD MSE: 0.05199395
# GPA_DS MSE: 0.00705040
# [TEST] image No.44
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05260601
# DS MSE: 0.00713856
# GPA_CD MSE: 0.05232403
# GPA_DS MSE: 0.00710102
# [TEST] image No.45
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05439090
# DS MSE: 0.00737238
# GPA_CD MSE: 0.05408987
# GPA_DS MSE: 0.00733276
# [TEST] image No.46
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05600624
# DS MSE: 0.00757293
# GPA_CD MSE: 0.05568733
# GPA_DS MSE: 0.00753147
# [TEST] image No.47
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05696734
# DS MSE: 0.00769624
# GPA_CD MSE: 0.05664017
# GPA_DS MSE: 0.00765389
# [TEST] image No.48
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05880963
# DS MSE: 0.00793612
# GPA_CD MSE: 0.05847164
# GPA_DS MSE: 0.00789257
# [TEST] image No.49
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05931232
# DS MSE: 0.00800638
# GPA_CD MSE: 0.05897095
# GPA_DS MSE: 0.00796249
# [TEST] image No.50
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.05975336
# DS MSE: 0.00806844
# GPA_CD MSE: 0.05940953
# GPA_DS MSE: 0.00802428
# [TEST] image No.51
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06137528
# DS MSE: 0.00826977
# GPA_CD MSE: 0.06102392
# GPA_DS MSE: 0.00822474
# [TEST] image No.52
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06300706
# DS MSE: 0.00849053
# GPA_CD MSE: 0.06264479
# GPA_DS MSE: 0.00844435
# [TEST] image No.53
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06359154
# DS MSE: 0.00857084
# GPA_CD MSE: 0.06321804
# GPA_DS MSE: 0.00852341
# [TEST] image No.54
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06483917
# DS MSE: 0.00874471
# GPA_CD MSE: 0.06445232
# GPA_DS MSE: 0.00869602
# [TEST] image No.55
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06581374
# DS MSE: 0.00942486
# GPA_CD MSE: 0.06546637
# GPA_DS MSE: 0.00942696
# [TEST] image No.56
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06622642
# DS MSE: 0.00948299
# GPA_CD MSE: 0.06588310
# GPA_DS MSE: 0.00948595
# [TEST] image No.57
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06799564
# DS MSE: 0.00971546
# GPA_CD MSE: 0.06765091
# GPA_DS MSE: 0.00971985
# [TEST] image No.58
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.06970431
# DS MSE: 0.00992844
# GPA_CD MSE: 0.06935678
# GPA_DS MSE: 0.00993252
# [TEST] image No.59
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07079042
# DS MSE: 0.01008098
# GPA_CD MSE: 0.07043394
# GPA_DS MSE: 0.01008410
# [TEST] image No.60
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07160643
# DS MSE: 0.01019727
# GPA_CD MSE: 0.07124285
# GPA_DS MSE: 0.01019986
# [TEST] image No.61
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07345924
# DS MSE: 0.01043564
# GPA_CD MSE: 0.07308406
# GPA_DS MSE: 0.01043708
# [TEST] image No.62
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07399663
# DS MSE: 0.01051032
# GPA_CD MSE: 0.07362056
# GPA_DS MSE: 0.01051177
# [TEST] image No.63
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07439625
# DS MSE: 0.01056663
# GPA_CD MSE: 0.07401386
# GPA_DS MSE: 0.01056776
# [TEST] image No.64
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07597284
# DS MSE: 0.01076227
# GPA_CD MSE: 0.07556127
# GPA_DS MSE: 0.01076044
# [TEST] image No.65
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07768600
# DS MSE: 0.01099104
# GPA_CD MSE: 0.07726486
# GPA_DS MSE: 0.01098820
# [TEST] image No.66
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.07920834
# DS MSE: 0.01119805
# GPA_CD MSE: 0.07877607
# GPA_DS MSE: 0.01119398
# [TEST] image No.67
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08038460
# DS MSE: 0.01136337
# GPA_CD MSE: 0.07994259
# GPA_DS MSE: 0.01135833
# [TEST] image No.68
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08106004
# DS MSE: 0.01146329
# GPA_CD MSE: 0.08060258
# GPA_DS MSE: 0.01145806
# [TEST] image No.69
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08161228
# DS MSE: 0.01153979
# GPA_CD MSE: 0.08115154
# GPA_DS MSE: 0.01153418
# [TEST] image No.70
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08241285
# DS MSE: 0.01165399
# GPA_CD MSE: 0.08194751
# GPA_DS MSE: 0.01164788
# [TEST] image No.71
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08401626
# DS MSE: 0.01187122
# GPA_CD MSE: 0.08354025
# GPA_DS MSE: 0.01186401
# [TEST] image No.72
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08583413
# DS MSE: 0.01210058
# GPA_CD MSE: 0.08534370
# GPA_DS MSE: 0.01209181
# [TEST] image No.73
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08659440
# DS MSE: 0.01220141
# GPA_CD MSE: 0.08610249
# GPA_DS MSE: 0.01219255
# [TEST] image No.74
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08808888
# DS MSE: 0.01240474
# GPA_CD MSE: 0.08758793
# GPA_DS MSE: 0.01239502
# [TEST] image No.75
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.08992179
# DS MSE: 0.01263750
# GPA_CD MSE: 0.08941051
# GPA_DS MSE: 0.01262671
# [TEST] image No.76
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09177423
# DS MSE: 0.01287541
# GPA_CD MSE: 0.09124973
# GPA_DS MSE: 0.01286322
# [TEST] image No.77
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09355500
# DS MSE: 0.01309833
# GPA_CD MSE: 0.09302215
# GPA_DS MSE: 0.01308522
# [TEST] image No.78
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09419551
# DS MSE: 0.01321125
# GPA_CD MSE: 0.09365792
# GPA_DS MSE: 0.01319554
# [TEST] image No.79
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09486926
# DS MSE: 0.01330180
# GPA_CD MSE: 0.09432450
# GPA_DS MSE: 0.01328526
# [TEST] image No.80
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09672192
# DS MSE: 0.01354177
# GPA_CD MSE: 0.09617164
# GPA_DS MSE: 0.01352477
# [TEST] image No.81
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09783430
# DS MSE: 0.01368184
# GPA_CD MSE: 0.09727600
# GPA_DS MSE: 0.01366398
# [TEST] image No.82
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09817770
# DS MSE: 0.01373146
# GPA_CD MSE: 0.09761738
# GPA_DS MSE: 0.01371370
# [TEST] image No.83
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.09994172
# DS MSE: 0.01395205
# GPA_CD MSE: 0.09937350
# GPA_DS MSE: 0.01393422
# [TEST] image No.84
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10069215
# DS MSE: 0.01405171
# GPA_CD MSE: 0.10011894
# GPA_DS MSE: 0.01403361
# [TEST] image No.85
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10211802
# DS MSE: 0.01422896
# GPA_CD MSE: 0.10153703
# GPA_DS MSE: 0.01421001
# [TEST] image No.86
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10352340
# DS MSE: 0.01440414
# GPA_CD MSE: 0.10293470
# GPA_DS MSE: 0.01438433
# [TEST] image No.87
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10523234
# DS MSE: 0.01463261
# GPA_CD MSE: 0.10463265
# GPA_DS MSE: 0.01461160
# [TEST] image No.88
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10708399
# DS MSE: 0.01487271
# GPA_CD MSE: 0.10647912
# GPA_DS MSE: 0.01485118
# [TEST] image No.89
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10858823
# DS MSE: 0.01505875
# GPA_CD MSE: 0.10797622
# GPA_DS MSE: 0.01503648
# [TEST] image No.90
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.10937841
# DS MSE: 0.01547744
# GPA_CD MSE: 0.10872351
# GPA_DS MSE: 0.01541178
# [TEST] image No.91
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11048265
# DS MSE: 0.01563256
# GPA_CD MSE: 0.10981732
# GPA_DS MSE: 0.01556577
# [TEST] image No.92
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11147492
# DS MSE: 0.01577253
# GPA_CD MSE: 0.11080844
# GPA_DS MSE: 0.01570559
# [TEST] image No.93
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11278988
# DS MSE: 0.01595367
# GPA_CD MSE: 0.11211466
# GPA_DS MSE: 0.01588581
# [TEST] image No.94
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11371771
# DS MSE: 0.01608516
# GPA_CD MSE: 0.11304540
# GPA_DS MSE: 0.01601774
# [TEST] image No.95
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11450630
# DS MSE: 0.01619775
# GPA_CD MSE: 0.11382587
# GPA_DS MSE: 0.01612948
# [TEST] image No.96
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11591271
# DS MSE: 0.01638954
# GPA_CD MSE: 0.11522511
# GPA_DS MSE: 0.01632049
# [TEST] image No.97
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11742288
# DS MSE: 0.01659496
# GPA_CD MSE: 0.11672687
# GPA_DS MSE: 0.01652495
# [TEST] image No.98
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.11927431
# DS MSE: 0.01683508
# GPA_CD MSE: 0.11857253
# GPA_DS MSE: 0.01676455
# [TEST] image No.99
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:100
# CD MSE: 0.12111977
# DS MSE: 0.01707064
# GPA_CD MSE: 0.12039955
# GPA_DS MSE: 0.01699806

# %%
DS_mse
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.017070636>

# %%
def plot_density(s, tick_list, f_true, classic_density_tensor, DS_tensor):
    density_true = f_true[:, s[0], s[1]]
    density_hat = classic_density_tensor[:, s[0], s[1]]
    density_doubly_all = DS_tensor[:, s[0], s[1]]
    plt.scatter(tick_list, density_true, marker='o', s=2, label=f"True at ({s[0]}, {s[1]})")
    plt.scatter(tick_list, density_hat, marker='^', s=1, label=f"Classical")
    plt.scatter(tick_list, density_doubly_all, marker='+', s=1, label=f"Doubly")
    
    plt.legend(loc=3)
    plt.show()

# %%
print("Sample size N:", N)
s = (100, 200)
plot_density(s, tick_list, f_true, classic_density_tensor, DS_tensor)
# Out:
# Sample size N: 1000

# %%
tick_list.shape
# Out:
# (500,)

# %%
density_true = f_true[:, s[0], s[1]]
density_classic = classic_density_tensor[:, s[0], s[1]]
density_doubly = DS_tensor[:, s[0], s[1]]

density_stats = {"tick": tick_list,
                "density_true": density_true,
                 "density_classic": density_classic,
                 "density_doubly": density_doubly}
density_stats_csv = pd.DataFrame(density_stats)
density_stats_csv.to_csv(f'./density_stats_N={N}.csv')

# %%
mse_classic = MSE(tf.squeeze(test_true_density), test_classic_density_tensor)
mse_doubly = MSE(tf.squeeze(test_true_density), test_DS_tensor)
mse_GPA = MSE(tf.squeeze(test_true_density), GPA_density)

mse_classic_median = MSE_median(tf.squeeze(test_true_density), test_classic_density_tensor)
mse_doubly_median = MSE_median(tf.squeeze(test_true_density), test_DS_tensor)
mse_GPA_median = MSE_median(tf.squeeze(test_true_density), GPA_density)


print(f"Sample size N:{N}")
print(f"h:{bandwidth} and h*:", {round(bandwidth_star, 4)})
print(f"classic density MSE:", {round(mse_classic.numpy(), 4)}, f"\tclassic density MSE_mean:", {round(mse_classic_median, 6)}, f'\tTime:{round(classic_time, 4)}')
print(f"doubly density MSE:", {round(mse_doubly.numpy(), 4)}, f"\tdoubly density MSE_mean:", {round(mse_doubly_median, 6)}, f'\tTime:{round(doubly_time, 4)}')
print(f"GPA density MSE:", {round(mse_GPA.numpy(), 4)}, f"\tGPA density MSE_mean:", {round(mse_GPA_median, 6)}, f'\tTime:{round(GPA_time, 4)}')
# Out:
# Sample size N:1000
# h:0.02315827506916077 and h*: {0.0034}
# classic density MSE: {0.0042} 	classic density MSE_mean: {0.000216} 	Time:19.811
# doubly density MSE: {0.0467} 	doubly density MSE_mean: {4.2e-05} 	Time:19.8383
# GPA density MSE: {0.0468} 	GPA density MSE_mean: {4.1e-05} 	Time:0.0185
