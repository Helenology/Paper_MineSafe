# %% [markdown]
# - Before move on, please run `install.sh` first.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os
import gc
import time
import numpy as np
import pandas as pd
import tensorflow as tf
# tf.debugging.set_log_device_placement(True)

# %matplotlib inline
from keras.preprocessing.image import array_to_img
import copy
import seaborn as sns
import cv2 as cv
import pickle
import tensorflow_probability as tfp
from tensorflow.keras.layers import AveragePooling2D
import shutil
import sys 

sys.path.append("../models/GPA")
sys.path.append("../")
from gpa import GPA
from utils import *
from simu_auxiliary import *

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1 Physical GPUs, 1 Logical GPUs
# 2024-05-04 03:27:18.382655: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-04 03:27:18.967563: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-SXM2-16GB, pci bus id: 0000:1f:00.0, compute capability: 6.0

# %%
def MSE(x, y):
    mse = tf.reduce_mean((x - y)**2)
    return mse

def MSE_median(x, y):
    mse = np.median((x - y)**2)
    return mse

# %%
T = 100                    # number of replications
N_list = [100, 500, 1000]  # number of images
p = 540
q = 960
G = 500

print(f"total replications T: {T}")
print(f"total sample size_list N_list:{N_list}")
print(f"image size p*q: {p}*{q}")
print(f"number of ticks on x axis G: {G}")
# Out:
# total replications T: 100
# total sample size_list N_list:[100, 500, 1000]
# image size p*q: 540*960
# number of ticks on x axis G: 500

# %%
avg_pool_2d_mean = AveragePooling2D(pool_size=(5, 5), strides=1, padding="same")
# the mean image
mean = np.load('./mean-540.npy')
mean = mean.reshape([1, p, q, 1])
mean = avg_pool_2d_mean(mean)
mean = tf.reshape(mean, (1, p, q))

show_img_one_channel(mean[0])
mean.shape
# Out:
# 2024-05-04 03:27:19.321997: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# TensorShape([1, 540, 960])

# %%
sigma = 0.2
test_size = 100

# %%
tick_list = np.random.uniform(size=G)
tick_tensor = tf.concat([tf.ones([1, p, q]) * tick for tick in tick_list], axis=0)

# %%
# true density
f_true = compute_true_density(tick_list, mean, sigma)

# location_weight
truncate_width = 3

tfd = tfp.distributions
dist = tfd.TruncatedNormal(loc=mean, scale=sigma, low=[0.], high=[1.])
# Out:
# True density shape: (500, 540, 960)

# %%
M = p * q

# %%
N = 1000
alpha = np.log(p*q) / np.log(N)
bandwidth, bandwidth_star = compute_optimal_bandwidths(N, M, sigma)
print(f"1/q / bandwidth:{1/q / bandwidth:.6f}")

N, bandwidth, bandwidth_star
# Out:
# Optimal bandwidth from Rule of Thumb: 0.015302491923891564
# Optimal bandwidth* from GPA estimation: 0.0011708312954038327
# 1/q / bandwidth:0.068072
# (1000, 0.015302491923891564, 0.0011708312954038327)

# %%
# N = 1000
# alpha = np.log(p*q) / np.log(N)
# bandwidth, bandwidth_star = compute_optimal_bandwidths(N, M, sigma)
# print(f"1/q / bandwidth:{1/q / bandwidth:.6f}")

# N, bandwidth, bandwidth_star

# %%
experiment_stats = {"N": [],
                    "t": [],
                    "CD_mse": [],
                    "DS_mse": [],
                    "GPA_CD_mse": [],
                    "GPA_DS_mse": [],
                    "DS_mse": [],
                    "CD_time": [],
                    "DS_time": [],
                    "GPA_CD_time": [],
                    "GPA_DS_time": []}

# %%
N_list = [500]

# %%
for N in N_list:
    print(f"============= N:{N} =============")
    alpha = np.log(p * q) / np.log(N)  # alpha
    path = f'../../../simulate_img_N={N}_GPU2'  # path to save N simulate image

    # optimal bandwidth
    bandwidth, bandwidth_star = compute_optimal_bandwidths(N, M, sigma)
    location_weight_tensor = compute_location_weight(p, q, bandwidth, truncate_width)
    location_weight_tensor = tf.reshape(location_weight_tensor, [truncate_width, truncate_width, 1, 1])
    location_weight_tensor = tf.cast(location_weight_tensor, tf.float32)

    for t in range(T): # repliacte
        print(f"============= The {t}th replication with N samlpes:{N} =============")
        seed = N + t
        tf.random.set_seed(seed) # set random seed in one replication of N
        np.random.seed(seed)
        CD_mse = 0
        DS_mse = 0
        GPA_CD_mse = 0
        GPA_DS_mse = 0
        CD_time = 0
        DS_time = 0
        GPA_CD_time = 0
        GPA_DS_time = 0
        
        # generate N generated N simulation images
        generate_simulate_data(path, N, mean, sigma)
        
        # pre-computed CD and DS matrix
        CD_matrix = compute_CD_matrix(path, N, G, p, q, bandwidth, tick_tensor)
        DS_matrix = compute_DS_matrix(CD_matrix, location_weight_tensor)
        CD_matrix = tf.squeeze(CD_matrix)
        DS_matrix = tf.squeeze(DS_matrix)
        
        # density comparison
        for test_i in range(test_size): # 生成测试图片
            print(f"[TEST] image No.{test_i}")
            test_img = tf.ones([p, q]) * np.random.uniform()
            oracle_test = tf.squeeze(dist.prob(test_img))
            
            # CD estimation
            print(f"[TEST] compute CD estimator")
            t1 = time.time()
            CD_test = test_CD(p, q, test_img, bandwidth, path)
            CD_test = tf.reshape(CD_test, (1, p, q))
            t2 = time.time()
            CD_time += (t2 - t1) / test_size
            
            # DS estimation
            print(f"[TEST] compute DS estimator")
            t3 = time.time()
            DS_test = compute_DS_matrix(CD_test, location_weight_tensor)
            t4 = time.time()
            DS_time += (t4 - t3 + t2 - t1) / test_size
            
            # GPA-CD estimation
            print(f"[TEST] compute GPA-CD estimator")
            t1 = time.time()
            Omega2_star = K_tf(tick_tensor - test_img, bandwidth_star)
            Omega1_star = Omega2_star * CD_matrix
            Omega1_star = tf.reduce_sum(Omega1_star, axis=0)
            Omega2_star = tf.reduce_sum(Omega2_star, axis=0)
            GPA_CD_test = Omega1_star / Omega2_star
            t2 = time.time()
            GPA_CD_time += (t2 - t1) / test_size
            
            # GPA-DS estimation
            print(f"[TEST] compute GPA-DS estimator")
            t1 = time.time()
            Omega2_star = K_tf(tick_tensor - test_img, bandwidth_star)
            Omega1_star = Omega2_star * DS_matrix
            Omega1_star = tf.reduce_sum(Omega1_star, axis=0)
            Omega2_star = tf.reduce_sum(Omega2_star, axis=0)
            GPA_DS_test = Omega1_star / Omega2_star
            t2 = time.time()
            GPA_DS_time += (t2 - t1) / test_size

            ###################### Compute MSE ####################
            # 1. MSE of the CD estimator
            CD_test = tf.squeeze(CD_test)
            CD_mse += MSE(oracle_test, CD_test) / test_size
            # 2. MSE of the DS estimator
            DS_test = tf.squeeze(DS_test)
            DS_mse += MSE(oracle_test, DS_test) / test_size
            # 3. MSE of the GPA-CD estimator
            GPA_CD_test = tf.squeeze(GPA_CD_test)
            GPA_CD_mse += MSE(oracle_test, GPA_CD_test) / test_size
            # 4. MSE of the GPA-DS estimator
            GPA_DS_test = tf.squeeze(GPA_DS_test)
            GPA_DS_mse += MSE(oracle_test, GPA_DS_test) / test_size
            print(f"Sample size N:{N}")
            print(f"CD MSE: {CD_mse.numpy():.8f}")
            print(f"DS MSE: {DS_mse.numpy():.8f}")
            print(f"GPA_CD MSE: {GPA_CD_mse.numpy():.8f}")
            print(f"GPA_DS MSE: {GPA_DS_mse.numpy():.8f}")
        
        experiment_stats["N"].append(N)
        experiment_stats["t"].append(t)
        experiment_stats["CD_mse"].append(CD_mse.numpy())
        experiment_stats["DS_mse"].append(DS_mse.numpy())
        experiment_stats["GPA_CD_mse"].append(GPA_CD_mse.numpy())
        experiment_stats["GPA_DS_mse"].append(GPA_DS_mse.numpy())
        experiment_stats["CD_time"].append(CD_time)
        experiment_stats["DS_time"].append(DS_time)
        experiment_stats["GPA_CD_time"].append(GPA_CD_time)
        experiment_stats["GPA_DS_time"].append(GPA_DS_time)
        experiment_stats_csv = pd.DataFrame(experiment_stats)
        experiment_stats_csv.to_csv(f'./simulation(N={N}).csv')
# Out:
# ============= N:500 =============
# Optimal bandwidth from Rule of Thumb: 0.016895320866246878
# Optimal bandwidth* from GPA estimation: 0.0014272593358671858
# ============= The 0th replication with N samlpes:500 =============
# -[CD] Successfully compute classical density with N=500 at ../../../simulate_img_N=500_GPU2
# [TEST] image No.0
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00028404
# DS MSE: 0.00004814
# GPA_CD MSE: 0.00028397
# GPA_DS MSE: 0.00004814
# [TEST] image No.1
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00047331
# DS MSE: 0.00009269
# GPA_CD MSE: 0.00047180
# GPA_DS MSE: 0.00009275
# [TEST] image No.2
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00078421
# DS MSE: 0.00014402
# GPA_CD MSE: 0.00078137
# GPA_DS MSE: 0.00014423
# [TEST] image No.3
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00119802
# DS MSE: 0.00021158
# GPA_CD MSE: 0.00119503
# GPA_DS MSE: 0.00021178
# [TEST] image No.4
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00141283
# DS MSE: 0.00026153
# GPA_CD MSE: 0.00141048
# GPA_DS MSE: 0.00026178
# [TEST] image No.5
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00189438
# DS MSE: 0.00034810
# GPA_CD MSE: 0.00188240
# GPA_DS MSE: 0.00034734
# [TEST] image No.6
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00235184
# DS MSE: 0.00042526
# GPA_CD MSE: 0.00233821
# GPA_DS MSE: 0.00042432
# [TEST] image No.7
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00281448
# DS MSE: 0.00051249
# GPA_CD MSE: 0.00279994
# GPA_DS MSE: 0.00051147
# [TEST] image No.8
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00328212
# DS MSE: 0.00059989
# GPA_CD MSE: 0.00326749
# GPA_DS MSE: 0.00059887
# [TEST] image No.9
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00375830
# DS MSE: 0.00068741
# GPA_CD MSE: 0.00374231
# GPA_DS MSE: 0.00068621
# [TEST] image No.10
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00390498
# DS MSE: 0.00071852
# GPA_CD MSE: 0.00388793
# GPA_DS MSE: 0.00071752
# [TEST] image No.11
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00438174
# DS MSE: 0.00080098
# GPA_CD MSE: 0.00436319
# GPA_DS MSE: 0.00079980
# [TEST] image No.12
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00483415
# DS MSE: 0.00088797
# GPA_CD MSE: 0.00481421
# GPA_DS MSE: 0.00088665
# [TEST] image No.13
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00530910
# DS MSE: 0.00097557
# GPA_CD MSE: 0.00528750
# GPA_DS MSE: 0.00097407
# [TEST] image No.14
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00578529
# DS MSE: 0.00105782
# GPA_CD MSE: 0.00576224
# GPA_DS MSE: 0.00105612
# [TEST] image No.15
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00589174
# DS MSE: 0.00108159
# GPA_CD MSE: 0.00586826
# GPA_DS MSE: 0.00107985
# [TEST] image No.16
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00636541
# DS MSE: 0.00116290
# GPA_CD MSE: 0.00634068
# GPA_DS MSE: 0.00116124
# [TEST] image No.17
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00678578
# DS MSE: 0.00124733
# GPA_CD MSE: 0.00676030
# GPA_DS MSE: 0.00124561
# [TEST] image No.18
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00689097
# DS MSE: 0.00127084
# GPA_CD MSE: 0.00686507
# GPA_DS MSE: 0.00126907
# [TEST] image No.19
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00736476
# DS MSE: 0.00135219
# GPA_CD MSE: 0.00733702
# GPA_DS MSE: 0.00135048
# [TEST] image No.20
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00779091
# DS MSE: 0.00142196
# GPA_CD MSE: 0.00776168
# GPA_DS MSE: 0.00142010
# [TEST] image No.21
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00807795
# DS MSE: 0.00147043
# GPA_CD MSE: 0.00804607
# GPA_DS MSE: 0.00146902
# [TEST] image No.22
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00823852
# DS MSE: 0.00150346
# GPA_CD MSE: 0.00820673
# GPA_DS MSE: 0.00150210
# [TEST] image No.23
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00858011
# DS MSE: 0.00155900
# GPA_CD MSE: 0.00854807
# GPA_DS MSE: 0.00155762
# [TEST] image No.24
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00890752
# DS MSE: 0.00161247
# GPA_CD MSE: 0.00887604
# GPA_DS MSE: 0.00161126
# [TEST] image No.25
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00899383
# DS MSE: 0.00163217
# GPA_CD MSE: 0.00896306
# GPA_DS MSE: 0.00163107
# [TEST] image No.26
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00939928
# DS MSE: 0.00169796
# GPA_CD MSE: 0.00936781
# GPA_DS MSE: 0.00169678
# [TEST] image No.27
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00974160
# DS MSE: 0.00175361
# GPA_CD MSE: 0.00970938
# GPA_DS MSE: 0.00175253
# [TEST] image No.28
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00990685
# DS MSE: 0.00179466
# GPA_CD MSE: 0.00986846
# GPA_DS MSE: 0.00179465
# [TEST] image No.29
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01013679
# DS MSE: 0.00183614
# GPA_CD MSE: 0.01009796
# GPA_DS MSE: 0.00183607
# [TEST] image No.30
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01027856
# DS MSE: 0.00186651
# GPA_CD MSE: 0.01023881
# GPA_DS MSE: 0.00186645
# [TEST] image No.31
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01074239
# DS MSE: 0.00194513
# GPA_CD MSE: 0.01070231
# GPA_DS MSE: 0.00194502
# [TEST] image No.32
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01112397
# DS MSE: 0.00202428
# GPA_CD MSE: 0.01108305
# GPA_DS MSE: 0.00202410
# [TEST] image No.33
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01157799
# DS MSE: 0.00210052
# GPA_CD MSE: 0.01154385
# GPA_DS MSE: 0.00210461
# [TEST] image No.34
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01185219
# DS MSE: 0.00216188
# GPA_CD MSE: 0.01181651
# GPA_DS MSE: 0.00216600
# [TEST] image No.35
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01216823
# DS MSE: 0.00223041
# GPA_CD MSE: 0.01213087
# GPA_DS MSE: 0.00223442
# [TEST] image No.36
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01240548
# DS MSE: 0.00228504
# GPA_CD MSE: 0.01236944
# GPA_DS MSE: 0.00228925
# [TEST] image No.37
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01279921
# DS MSE: 0.00236576
# GPA_CD MSE: 0.01276747
# GPA_DS MSE: 0.00237205
# [TEST] image No.38
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01311584
# DS MSE: 0.00241782
# GPA_CD MSE: 0.01308304
# GPA_DS MSE: 0.00242464
# [TEST] image No.39
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01349306
# DS MSE: 0.00247859
# GPA_CD MSE: 0.01345970
# GPA_DS MSE: 0.00248534
# [TEST] image No.40
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01380918
# DS MSE: 0.00253058
# GPA_CD MSE: 0.01377496
# GPA_DS MSE: 0.00253756
# [TEST] image No.41
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01391267
# DS MSE: 0.00255373
# GPA_CD MSE: 0.01387787
# GPA_DS MSE: 0.00256066
# [TEST] image No.42
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01399828
# DS MSE: 0.00257335
# GPA_CD MSE: 0.01396232
# GPA_DS MSE: 0.00258066
# [TEST] image No.43
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01416434
# DS MSE: 0.00260712
# GPA_CD MSE: 0.01412686
# GPA_DS MSE: 0.00261430
# [TEST] image No.44
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01443708
# DS MSE: 0.00266824
# GPA_CD MSE: 0.01439818
# GPA_DS MSE: 0.00267535
# [TEST] image No.45
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01464820
# DS MSE: 0.00270759
# GPA_CD MSE: 0.01460932
# GPA_DS MSE: 0.00271475
# [TEST] image No.46
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01505092
# DS MSE: 0.00277279
# GPA_CD MSE: 0.01501472
# GPA_DS MSE: 0.00278123
# [TEST] image No.47
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01528423
# DS MSE: 0.00281466
# GPA_CD MSE: 0.01524639
# GPA_DS MSE: 0.00282328
# [TEST] image No.48
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01569799
# DS MSE: 0.00289830
# GPA_CD MSE: 0.01565844
# GPA_DS MSE: 0.00290676
# [TEST] image No.49
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01582137
# DS MSE: 0.00292553
# GPA_CD MSE: 0.01578448
# GPA_DS MSE: 0.00293493
# [TEST] image No.50
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01624677
# DS MSE: 0.00301045
# GPA_CD MSE: 0.01621599
# GPA_DS MSE: 0.00302406
# [TEST] image No.51
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01664920
# DS MSE: 0.00309240
# GPA_CD MSE: 0.01661701
# GPA_DS MSE: 0.00310677
# [TEST] image No.52
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01712830
# DS MSE: 0.00317580
# GPA_CD MSE: 0.01709325
# GPA_DS MSE: 0.00318983
# [TEST] image No.53
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01738003
# DS MSE: 0.00321998
# GPA_CD MSE: 0.01734473
# GPA_DS MSE: 0.00323403
# [TEST] image No.54
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01762613
# DS MSE: 0.00327630
# GPA_CD MSE: 0.01758964
# GPA_DS MSE: 0.00329027
# [TEST] image No.55
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01780864
# DS MSE: 0.00331940
# GPA_CD MSE: 0.01777185
# GPA_DS MSE: 0.00333332
# [TEST] image No.56
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01792153
# DS MSE: 0.00334454
# GPA_CD MSE: 0.01788478
# GPA_DS MSE: 0.00335847
# [TEST] image No.57
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01826444
# DS MSE: 0.00340027
# GPA_CD MSE: 0.01822666
# GPA_DS MSE: 0.00341457
# [TEST] image No.58
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01836053
# DS MSE: 0.00342190
# GPA_CD MSE: 0.01832307
# GPA_DS MSE: 0.00343625
# [TEST] image No.59
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01847061
# DS MSE: 0.00344644
# GPA_CD MSE: 0.01843261
# GPA_DS MSE: 0.00346073
# [TEST] image No.60
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01870571
# DS MSE: 0.00350065
# GPA_CD MSE: 0.01866571
# GPA_DS MSE: 0.00351481
# [TEST] image No.61
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01894403
# DS MSE: 0.00354314
# GPA_CD MSE: 0.01890307
# GPA_DS MSE: 0.00355729
# [TEST] image No.62
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01917125
# DS MSE: 0.00358430
# GPA_CD MSE: 0.01913318
# GPA_DS MSE: 0.00359964
# [TEST] image No.63
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01963941
# DS MSE: 0.00367173
# GPA_CD MSE: 0.01960025
# GPA_DS MSE: 0.00368701
# [TEST] image No.64
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01994744
# DS MSE: 0.00393950
# GPA_CD MSE: 0.01992151
# GPA_DS MSE: 0.00396935
# [TEST] image No.65
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02033431
# DS MSE: 0.00400174
# GPA_CD MSE: 0.02030716
# GPA_DS MSE: 0.00403151
# [TEST] image No.66
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02069197
# DS MSE: 0.00407701
# GPA_CD MSE: 0.02066276
# GPA_DS MSE: 0.00410662
# [TEST] image No.67
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02089198
# DS MSE: 0.00411503
# GPA_CD MSE: 0.02086147
# GPA_DS MSE: 0.00414450
# [TEST] image No.68
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02106450
# DS MSE: 0.00414969
# GPA_CD MSE: 0.02103296
# GPA_DS MSE: 0.00417904
# [TEST] image No.69
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02135281
# DS MSE: 0.00419829
# GPA_CD MSE: 0.02131912
# GPA_DS MSE: 0.00422759
# [TEST] image No.70
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02165938
# DS MSE: 0.00424906
# GPA_CD MSE: 0.02162634
# GPA_DS MSE: 0.00427882
# [TEST] image No.71
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02184457
# DS MSE: 0.00428530
# GPA_CD MSE: 0.02181008
# GPA_DS MSE: 0.00431533
# [TEST] image No.72
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02195946
# DS MSE: 0.00434593
# GPA_CD MSE: 0.02192716
# GPA_DS MSE: 0.00437862
# [TEST] image No.73
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02242739
# DS MSE: 0.00443334
# GPA_CD MSE: 0.02239463
# GPA_DS MSE: 0.00446597
# [TEST] image No.74
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02288491
# DS MSE: 0.00485771
# GPA_CD MSE: 0.02286979
# GPA_DS MSE: 0.00490877
# [TEST] image No.75
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02335601
# DS MSE: 0.00494527
# GPA_CD MSE: 0.02333670
# GPA_DS MSE: 0.00499602
# [TEST] image No.76
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02380328
# DS MSE: 0.00535896
# GPA_CD MSE: 0.02380460
# GPA_DS MSE: 0.00543126
# [TEST] image No.77
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02420198
# DS MSE: 0.00542331
# GPA_CD MSE: 0.02420251
# GPA_DS MSE: 0.00549605
# [TEST] image No.78
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02444247
# DS MSE: 0.00546607
# GPA_CD MSE: 0.02444206
# GPA_DS MSE: 0.00553900
# [TEST] image No.79
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02469967
# DS MSE: 0.00551094
# GPA_CD MSE: 0.02469814
# GPA_DS MSE: 0.00558375
# [TEST] image No.80
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02485649
# DS MSE: 0.00554347
# GPA_CD MSE: 0.02485450
# GPA_DS MSE: 0.00561624
# [TEST] image No.81
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02530706
# DS MSE: 0.00561867
# GPA_CD MSE: 0.02530506
# GPA_DS MSE: 0.00569280
# [TEST] image No.82
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02552698
# DS MSE: 0.00565902
# GPA_CD MSE: 0.02552358
# GPA_DS MSE: 0.00573305
# [TEST] image No.83
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02591175
# DS MSE: 0.00573858
# GPA_CD MSE: 0.02590722
# GPA_DS MSE: 0.00581253
# [TEST] image No.84
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02626578
# DS MSE: 0.00579600
# GPA_CD MSE: 0.02626103
# GPA_DS MSE: 0.00587013
# [TEST] image No.85
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02634862
# DS MSE: 0.00581595
# GPA_CD MSE: 0.02634367
# GPA_DS MSE: 0.00588982
# [TEST] image No.86
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02677890
# DS MSE: 0.00590129
# GPA_CD MSE: 0.02677241
# GPA_DS MSE: 0.00597506
# [TEST] image No.87
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02694278
# DS MSE: 0.00594328
# GPA_CD MSE: 0.02693994
# GPA_DS MSE: 0.00602421
# [TEST] image No.88
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02735574
# DS MSE: 0.00602681
# GPA_CD MSE: 0.02735178
# GPA_DS MSE: 0.00610761
# [TEST] image No.89
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02745113
# DS MSE: 0.00604829
# GPA_CD MSE: 0.02744835
# GPA_DS MSE: 0.00612938
# [TEST] image No.90
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02758749
# DS MSE: 0.00607780
# GPA_CD MSE: 0.02758293
# GPA_DS MSE: 0.00615888
# [TEST] image No.91
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02801797
# DS MSE: 0.00614834
# GPA_CD MSE: 0.02801453
# GPA_DS MSE: 0.00622992
# [TEST] image No.92
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02826503
# DS MSE: 0.00620483
# GPA_CD MSE: 0.02826009
# GPA_DS MSE: 0.00628627
# [TEST] image No.93
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02837452
# DS MSE: 0.00622924
# GPA_CD MSE: 0.02836926
# GPA_DS MSE: 0.00631065
# [TEST] image No.94
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02847704
# DS MSE: 0.00625219
# GPA_CD MSE: 0.02847168
# GPA_DS MSE: 0.00633359
# [TEST] image No.95
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02868144
# DS MSE: 0.00629074
# GPA_CD MSE: 0.02867466
# GPA_DS MSE: 0.00637223
# [TEST] image No.96
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02896709
# DS MSE: 0.00633906
# GPA_CD MSE: 0.02895928
# GPA_DS MSE: 0.00642067
# [TEST] image No.97
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02934997
# DS MSE: 0.00641838
# GPA_CD MSE: 0.02934071
# GPA_DS MSE: 0.00649985
# [TEST] image No.98
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02982443
# DS MSE: 0.00650599
# GPA_CD MSE: 0.02981424
# GPA_DS MSE: 0.00658744
# [TEST] image No.99
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.03007228
# DS MSE: 0.00654968
# GPA_CD MSE: 0.03006095
# GPA_DS MSE: 0.00663102
# ============= The 1th replication with N samlpes:500 =============
# -[CD] Successfully compute classical density with N=500 at ../../../simulate_img_N=500_GPU2
# [TEST] image No.0
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00035395
# DS MSE: 0.00007504
# GPA_CD MSE: 0.00035245
# GPA_DS MSE: 0.00007494
# [TEST] image No.1
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00080292
# DS MSE: 0.00014937
# GPA_CD MSE: 0.00080068
# GPA_DS MSE: 0.00014918
# [TEST] image No.2
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00098997
# DS MSE: 0.00019323
# GPA_CD MSE: 0.00098625
# GPA_DS MSE: 0.00019304
# [TEST] image No.3
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00123440
# DS MSE: 0.00034332
# GPA_CD MSE: 0.00123359
# GPA_DS MSE: 0.00034641
# [TEST] image No.4
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00145599
# DS MSE: 0.00038381
# GPA_CD MSE: 0.00145366
# GPA_DS MSE: 0.00038690
# [TEST] image No.5
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00177807
# DS MSE: 0.00043680
# GPA_CD MSE: 0.00177770
# GPA_DS MSE: 0.00044056
# [TEST] image No.6
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00225476
# DS MSE: 0.00051821
# GPA_CD MSE: 0.00225314
# GPA_DS MSE: 0.00052184
# [TEST] image No.7
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00270979
# DS MSE: 0.00060543
# GPA_CD MSE: 0.00270638
# GPA_DS MSE: 0.00060892
# [TEST] image No.8
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00283042
# DS MSE: 0.00063218
# GPA_CD MSE: 0.00282591
# GPA_DS MSE: 0.00063633
# [TEST] image No.9
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00297953
# DS MSE: 0.00066346
# GPA_CD MSE: 0.00297714
# GPA_DS MSE: 0.00066830
# [TEST] image No.10
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00336913
# DS MSE: 0.00074311
# GPA_CD MSE: 0.00336542
# GPA_DS MSE: 0.00074986
# [TEST] image No.11
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00353109
# DS MSE: 0.00077634
# GPA_CD MSE: 0.00352661
# GPA_DS MSE: 0.00078301
# [TEST] image No.12
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00386065
# DS MSE: 0.00083031
# GPA_CD MSE: 0.00385537
# GPA_DS MSE: 0.00083698
# [TEST] image No.13
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00419004
# DS MSE: 0.00088427
# GPA_CD MSE: 0.00418406
# GPA_DS MSE: 0.00089091
# [TEST] image No.14
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00448870
# DS MSE: 0.00093380
# GPA_CD MSE: 0.00448017
# GPA_DS MSE: 0.00094031
# [TEST] image No.15
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00497228
# DS MSE: 0.00101888
# GPA_CD MSE: 0.00496234
# GPA_DS MSE: 0.00102527
# [TEST] image No.16
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00510545
# DS MSE: 0.00104768
# GPA_CD MSE: 0.00509525
# GPA_DS MSE: 0.00105405
# [TEST] image No.17
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00535282
# DS MSE: 0.00110419
# GPA_CD MSE: 0.00534191
# GPA_DS MSE: 0.00111044
# [TEST] image No.18
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00575797
# DS MSE: 0.00116959
# GPA_CD MSE: 0.00574617
# GPA_DS MSE: 0.00117576
# [TEST] image No.19
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00592797
# DS MSE: 0.00121038
# GPA_CD MSE: 0.00591599
# GPA_DS MSE: 0.00121658
# [TEST] image No.20
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00614757
# DS MSE: 0.00125063
# GPA_CD MSE: 0.00613440
# GPA_DS MSE: 0.00125675
# [TEST] image No.21
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00663079
# DS MSE: 0.00133792
# GPA_CD MSE: 0.00661787
# GPA_DS MSE: 0.00134484
# [TEST] image No.22
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00696282
# DS MSE: 0.00139220
# GPA_CD MSE: 0.00694447
# GPA_DS MSE: 0.00139853
# [TEST] image No.23
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00728321
# DS MSE: 0.00144495
# GPA_CD MSE: 0.00726955
# GPA_DS MSE: 0.00145376
# [TEST] image No.24
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00737279
# DS MSE: 0.00146530
# GPA_CD MSE: 0.00735896
# GPA_DS MSE: 0.00147409
# [TEST] image No.25
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00755799
# DS MSE: 0.00150879
# GPA_CD MSE: 0.00754322
# GPA_DS MSE: 0.00151761
# [TEST] image No.26
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00784993
# DS MSE: 0.00157334
# GPA_CD MSE: 0.00783179
# GPA_DS MSE: 0.00158203
# [TEST] image No.27
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00822363
# DS MSE: 0.00165100
# GPA_CD MSE: 0.00820387
# GPA_DS MSE: 0.00166091
# [TEST] image No.28
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00870721
# DS MSE: 0.00173801
# GPA_CD MSE: 0.00868814
# GPA_DS MSE: 0.00174856
# [TEST] image No.29
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00909520
# DS MSE: 0.00180033
# GPA_CD MSE: 0.00907308
# GPA_DS MSE: 0.00181059
# [TEST] image No.30
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00949275
# DS MSE: 0.00186436
# GPA_CD MSE: 0.00946976
# GPA_DS MSE: 0.00187520
# [TEST] image No.31
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00971384
# DS MSE: 0.00190478
# GPA_CD MSE: 0.00968929
# GPA_DS MSE: 0.00191558
# [TEST] image No.32
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01010966
# DS MSE: 0.00196849
# GPA_CD MSE: 0.01008449
# GPA_DS MSE: 0.00197923
# [TEST] image No.33
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01050360
# DS MSE: 0.00203186
# GPA_CD MSE: 0.01047678
# GPA_DS MSE: 0.00204244
# [TEST] image No.34
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01109919
# DS MSE: 0.00256921
# GPA_CD MSE: 0.01110329
# GPA_DS MSE: 0.00261259
# [TEST] image No.35
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01127841
# DS MSE: 0.00261148
# GPA_CD MSE: 0.01128120
# GPA_DS MSE: 0.00265489
# [TEST] image No.36
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01153942
# DS MSE: 0.00267051
# GPA_CD MSE: 0.01154011
# GPA_DS MSE: 0.00271393
# [TEST] image No.37
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01196606
# DS MSE: 0.00273992
# GPA_CD MSE: 0.01196385
# GPA_DS MSE: 0.00278308
# [TEST] image No.38
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01230352
# DS MSE: 0.00281214
# GPA_CD MSE: 0.01229998
# GPA_DS MSE: 0.00285748
# [TEST] image No.39
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01248757
# DS MSE: 0.00284832
# GPA_CD MSE: 0.01248352
# GPA_DS MSE: 0.00289362
# [TEST] image No.40
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01284378
# DS MSE: 0.00292369
# GPA_CD MSE: 0.01283775
# GPA_DS MSE: 0.00296886
# [TEST] image No.41
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01296764
# DS MSE: 0.00295101
# GPA_CD MSE: 0.01296308
# GPA_DS MSE: 0.00299659
# [TEST] image No.42
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01313089
# DS MSE: 0.00298443
# GPA_CD MSE: 0.01312565
# GPA_DS MSE: 0.00302995
# [TEST] image No.43
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01360180
# DS MSE: 0.00307201
# GPA_CD MSE: 0.01359326
# GPA_DS MSE: 0.00311742
# [TEST] image No.44
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01391457
# DS MSE: 0.00312360
# GPA_CD MSE: 0.01390299
# GPA_DS MSE: 0.00316904
# [TEST] image No.45
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01425992
# DS MSE: 0.00319728
# GPA_CD MSE: 0.01424923
# GPA_DS MSE: 0.00324304
# [TEST] image No.46
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01449759
# DS MSE: 0.00323963
# GPA_CD MSE: 0.01448663
# GPA_DS MSE: 0.00328536
# [TEST] image No.47
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01514783
# DS MSE: 0.00386415
# GPA_CD MSE: 0.01500556
# GPA_DS MSE: 0.00377420
# [TEST] image No.48
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01554426
# DS MSE: 0.00392797
# GPA_CD MSE: 0.01540128
# GPA_DS MSE: 0.00383803
# [TEST] image No.49
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01602523
# DS MSE: 0.00401106
# GPA_CD MSE: 0.01587976
# GPA_DS MSE: 0.00392084
# [TEST] image No.50
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01611083
# DS MSE: 0.00403067
# GPA_CD MSE: 0.01596483
# GPA_DS MSE: 0.00394081
# [TEST] image No.51
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01629179
# DS MSE: 0.00410324
# GPA_CD MSE: 0.01613671
# GPA_DS MSE: 0.00400187
# [TEST] image No.52
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01706191
# DS MSE: 0.00482680
# GPA_CD MSE: 0.01672057
# GPA_DS MSE: 0.00452865
# [TEST] image No.53
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01726181
# DS MSE: 0.00492367
# GPA_CD MSE: 0.01691158
# GPA_DS MSE: 0.00461869
# [TEST] image No.54
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01757851
# DS MSE: 0.00497587
# GPA_CD MSE: 0.01722746
# GPA_DS MSE: 0.00467096
# [TEST] image No.55
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01774625
# DS MSE: 0.00501663
# GPA_CD MSE: 0.01739766
# GPA_DS MSE: 0.00471113
# [TEST] image No.56
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01794517
# DS MSE: 0.00505454
# GPA_CD MSE: 0.01759556
# GPA_DS MSE: 0.00474893
# [TEST] image No.57
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01839527
# DS MSE: 0.00514137
# GPA_CD MSE: 0.01804136
# GPA_DS MSE: 0.00483534
# [TEST] image No.58
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01848793
# DS MSE: 0.00516241
# GPA_CD MSE: 0.01813331
# GPA_DS MSE: 0.00485646
# [TEST] image No.59
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01863495
# DS MSE: 0.00519338
# GPA_CD MSE: 0.01827902
# GPA_DS MSE: 0.00488778
# [TEST] image No.60
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01911862
# DS MSE: 0.00527992
# GPA_CD MSE: 0.01876135
# GPA_DS MSE: 0.00497420
# [TEST] image No.61
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01958908
# DS MSE: 0.00535964
# GPA_CD MSE: 0.01922970
# GPA_DS MSE: 0.00505382
# [TEST] image No.62
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01983686
# DS MSE: 0.00540315
# GPA_CD MSE: 0.01947602
# GPA_DS MSE: 0.00509720
# [TEST] image No.63
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02006952
# DS MSE: 0.00544493
# GPA_CD MSE: 0.01970732
# GPA_DS MSE: 0.00513900
# [TEST] image No.64
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02052815
# DS MSE: 0.00552177
# GPA_CD MSE: 0.02016489
# GPA_DS MSE: 0.00521579
# [TEST] image No.65
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02101175
# DS MSE: 0.00560711
# GPA_CD MSE: 0.02064540
# GPA_DS MSE: 0.00530097
# [TEST] image No.66
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02140778
# DS MSE: 0.00567086
# GPA_CD MSE: 0.02104080
# GPA_DS MSE: 0.00536467
# [TEST] image No.67
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02187084
# DS MSE: 0.00575850
# GPA_CD MSE: 0.02150294
# GPA_DS MSE: 0.00545222
# [TEST] image No.68
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02211033
# DS MSE: 0.00581344
# GPA_CD MSE: 0.02174203
# GPA_DS MSE: 0.00550713
# [TEST] image No.69
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02237043
# DS MSE: 0.00585841
# GPA_CD MSE: 0.02200110
# GPA_DS MSE: 0.00555200
# [TEST] image No.70
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02282220
# DS MSE: 0.00593352
# GPA_CD MSE: 0.02245503
# GPA_DS MSE: 0.00563161
# [TEST] image No.71
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02329322
# DS MSE: 0.00602109
# GPA_CD MSE: 0.02292362
# GPA_DS MSE: 0.00571927
# [TEST] image No.72
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02367260
# DS MSE: 0.00609948
# GPA_CD MSE: 0.02330372
# GPA_DS MSE: 0.00579787
# [TEST] image No.73
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02405914
# DS MSE: 0.00616155
# GPA_CD MSE: 0.02368882
# GPA_DS MSE: 0.00585988
# [TEST] image No.74
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02426298
# DS MSE: 0.00620001
# GPA_CD MSE: 0.02389237
# GPA_DS MSE: 0.00589830
# [TEST] image No.75
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02438097
# DS MSE: 0.00622624
# GPA_CD MSE: 0.02400978
# GPA_DS MSE: 0.00592447
# [TEST] image No.76
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02485810
# DS MSE: 0.00630780
# GPA_CD MSE: 0.02448498
# GPA_DS MSE: 0.00600587
# [TEST] image No.77
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02523654
# DS MSE: 0.00636856
# GPA_CD MSE: 0.02486216
# GPA_DS MSE: 0.00606654
# [TEST] image No.78
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02553911
# DS MSE: 0.00641862
# GPA_CD MSE: 0.02516496
# GPA_DS MSE: 0.00611664
# [TEST] image No.79
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02585864
# DS MSE: 0.00647124
# GPA_CD MSE: 0.02547787
# GPA_DS MSE: 0.00616890
# [TEST] image No.80
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02624064
# DS MSE: 0.00654995
# GPA_CD MSE: 0.02585841
# GPA_DS MSE: 0.00624746
# [TEST] image No.81
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02683613
# DS MSE: 0.00708719
# GPA_CD MSE: 0.02648495
# GPA_DS MSE: 0.00681764
# [TEST] image No.82
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02695059
# DS MSE: 0.00711271
# GPA_CD MSE: 0.02659875
# GPA_DS MSE: 0.00684309
# [TEST] image No.83
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02733772
# DS MSE: 0.00719205
# GPA_CD MSE: 0.02698472
# GPA_DS MSE: 0.00692257
# [TEST] image No.84
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02782093
# DS MSE: 0.00727648
# GPA_CD MSE: 0.02746586
# GPA_DS MSE: 0.00700702
# [TEST] image No.85
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02809360
# DS MSE: 0.00733757
# GPA_CD MSE: 0.02773663
# GPA_DS MSE: 0.00706810
# [TEST] image No.86
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02853884
# DS MSE: 0.00742403
# GPA_CD MSE: 0.02817798
# GPA_DS MSE: 0.00715421
# [TEST] image No.87
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02877294
# DS MSE: 0.00747787
# GPA_CD MSE: 0.02841124
# GPA_DS MSE: 0.00720805
# [TEST] image No.88
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02922595
# DS MSE: 0.00756493
# GPA_CD MSE: 0.02886302
# GPA_DS MSE: 0.00729507
# [TEST] image No.89
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02943036
# DS MSE: 0.00760345
# GPA_CD MSE: 0.02906675
# GPA_DS MSE: 0.00733355
# [TEST] image No.90
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02970939
# DS MSE: 0.00765067
# GPA_CD MSE: 0.02934500
# GPA_DS MSE: 0.00738070
# [TEST] image No.91
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.03015337
# DS MSE: 0.00773703
# GPA_CD MSE: 0.02978826
# GPA_DS MSE: 0.00746699
# [TEST] image No.92
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.03047681
# DS MSE: 0.00779021
# GPA_CD MSE: 0.03011170
# GPA_DS MSE: 0.00752017
# [TEST] image No.93
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.03081392
# DS MSE: 0.00784512
# GPA_CD MSE: 0.03044757
# GPA_DS MSE: 0.00757523
# [TEST] image No.94
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.03128656
# DS MSE: 0.00793269
# GPA_CD MSE: 0.03091957
# GPA_DS MSE: 0.00766271
# [TEST] image No.95
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.03152315
# DS MSE: 0.00798705
# GPA_CD MSE: 0.03115608
# GPA_DS MSE: 0.00771706
# [TEST] image No.96
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.03172744
# DS MSE: 0.00802555
# GPA_CD MSE: 0.03135977
# GPA_DS MSE: 0.00775553
# [TEST] image No.97
# [TEST] compute CD estimator
# ...
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02146450
# DS MSE: 0.00472246
# GPA_CD MSE: 0.02111687
# GPA_DS MSE: 0.00443439
# [TEST] image No.72
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02187935
# DS MSE: 0.00480536
# GPA_CD MSE: 0.02152835
# GPA_DS MSE: 0.00451691
# [TEST] image No.73
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02217953
# DS MSE: 0.00485530
# GPA_CD MSE: 0.02183024
# GPA_DS MSE: 0.00456746
# [TEST] image No.74
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02228551
# DS MSE: 0.00487926
# GPA_CD MSE: 0.02193582
# GPA_DS MSE: 0.00459138
# [TEST] image No.75
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02263156
# DS MSE: 0.00495259
# GPA_CD MSE: 0.02228272
# GPA_DS MSE: 0.00466501
# [TEST] image No.76
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02291305
# DS MSE: 0.00499997
# GPA_CD MSE: 0.02256218
# GPA_DS MSE: 0.00471221
# [TEST] image No.77
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02322618
# DS MSE: 0.00506810
# GPA_CD MSE: 0.02287610
# GPA_DS MSE: 0.00478050
# [TEST] image No.78
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02369832
# DS MSE: 0.00514818
# GPA_CD MSE: 0.02334612
# GPA_DS MSE: 0.00486051
# [TEST] image No.79
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02378537
# DS MSE: 0.00517650
# GPA_CD MSE: 0.02343283
# GPA_DS MSE: 0.00488876
# [TEST] image No.80
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02396955
# DS MSE: 0.00521251
# GPA_CD MSE: 0.02361620
# GPA_DS MSE: 0.00492480
# [TEST] image No.81
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02442773
# DS MSE: 0.00528890
# GPA_CD MSE: 0.02407331
# GPA_DS MSE: 0.00500105
# [TEST] image No.82
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02488677
# DS MSE: 0.00536550
# GPA_CD MSE: 0.02453067
# GPA_DS MSE: 0.00507748
# [TEST] image No.83
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02536615
# DS MSE: 0.00544885
# GPA_CD MSE: 0.02500756
# GPA_DS MSE: 0.00516053
# [TEST] image No.84
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02584968
# DS MSE: 0.00553532
# GPA_CD MSE: 0.02548794
# GPA_DS MSE: 0.00524665
# [TEST] image No.85
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02611743
# DS MSE: 0.00558111
# GPA_CD MSE: 0.02575470
# GPA_DS MSE: 0.00529234
# [TEST] image No.86
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02629934
# DS MSE: 0.00562336
# GPA_CD MSE: 0.02593718
# GPA_DS MSE: 0.00533455
# [TEST] image No.87
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02670546
# DS MSE: 0.00568917
# GPA_CD MSE: 0.02634143
# GPA_DS MSE: 0.00540026
# [TEST] image No.88
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02688357
# DS MSE: 0.00572445
# GPA_CD MSE: 0.02651813
# GPA_DS MSE: 0.00543547
# [TEST] image No.89
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02734639
# DS MSE: 0.00580204
# GPA_CD MSE: 0.02698035
# GPA_DS MSE: 0.00551299
# [TEST] image No.90
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02751205
# DS MSE: 0.00584230
# GPA_CD MSE: 0.02714949
# GPA_DS MSE: 0.00555267
# [TEST] image No.91
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02776999
# DS MSE: 0.00588706
# GPA_CD MSE: 0.02740630
# GPA_DS MSE: 0.00559733
# [TEST] image No.92
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02792674
# DS MSE: 0.00591945
# GPA_CD MSE: 0.02756193
# GPA_DS MSE: 0.00562960
# [TEST] image No.93
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02832711
# DS MSE: 0.00600028
# GPA_CD MSE: 0.02796109
# GPA_DS MSE: 0.00571045
# [TEST] image No.94
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02852156
# DS MSE: 0.00603762
# GPA_CD MSE: 0.02815658
# GPA_DS MSE: 0.00574813
# [TEST] image No.95
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02897297
# DS MSE: 0.00612465
# GPA_CD MSE: 0.02860701
# GPA_DS MSE: 0.00583516
# [TEST] image No.96
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02945157
# DS MSE: 0.00620749
# GPA_CD MSE: 0.02908398
# GPA_DS MSE: 0.00591780
# [TEST] image No.97
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02955677
# DS MSE: 0.00623128
# GPA_CD MSE: 0.02918875
# GPA_DS MSE: 0.00594155
# [TEST] image No.98
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.02966686
# DS MSE: 0.00625604
# GPA_CD MSE: 0.02929829
# GPA_DS MSE: 0.00596627
# [TEST] image No.99
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.03009492
# DS MSE: 0.00634050
# GPA_CD MSE: 0.02973075
# GPA_DS MSE: 0.00605311
# ============= The 97th replication with N samlpes:500 =============
# -[CD] Successfully compute classical density with N=500 at ../../../simulate_img_N=500_GPU2
# [TEST] image No.0
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00026859
# DS MSE: 0.00004638
# GPA_CD MSE: 0.00026726
# GPA_DS MSE: 0.00004628
# [TEST] image No.1
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00070566
# DS MSE: 0.00011824
# GPA_CD MSE: 0.00070246
# GPA_DS MSE: 0.00011806
# [TEST] image No.2
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00085681
# DS MSE: 0.00014999
# GPA_CD MSE: 0.00085321
# GPA_DS MSE: 0.00014978
# [TEST] image No.3
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00116976
# DS MSE: 0.00020142
# GPA_CD MSE: 0.00116249
# GPA_DS MSE: 0.00020082
# [TEST] image No.4
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00161993
# DS MSE: 0.00028823
# GPA_CD MSE: 0.00161182
# GPA_DS MSE: 0.00028767
# [TEST] image No.5
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00193394
# DS MSE: 0.00033978
# GPA_CD MSE: 0.00192610
# GPA_DS MSE: 0.00033938
# [TEST] image No.6
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00223074
# DS MSE: 0.00038943
# GPA_CD MSE: 0.00222234
# GPA_DS MSE: 0.00038900
# [TEST] image No.7
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00252050
# DS MSE: 0.00045315
# GPA_CD MSE: 0.00251019
# GPA_DS MSE: 0.00045370
# [TEST] image No.8
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00278648
# DS MSE: 0.00049923
# GPA_CD MSE: 0.00277513
# GPA_DS MSE: 0.00049967
# [TEST] image No.9
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00325749
# DS MSE: 0.00058698
# GPA_CD MSE: 0.00324332
# GPA_DS MSE: 0.00058710
# [TEST] image No.10
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00371385
# DS MSE: 0.00067421
# GPA_CD MSE: 0.00369761
# GPA_DS MSE: 0.00067408
# [TEST] image No.11
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00385571
# DS MSE: 0.00070460
# GPA_CD MSE: 0.00383852
# GPA_DS MSE: 0.00070445
# [TEST] image No.12
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00396961
# DS MSE: 0.00072984
# GPA_CD MSE: 0.00395144
# GPA_DS MSE: 0.00072960
# [TEST] image No.13
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00440264
# DS MSE: 0.00080081
# GPA_CD MSE: 0.00438404
# GPA_DS MSE: 0.00080063
# [TEST] image No.14
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00473225
# DS MSE: 0.00085448
# GPA_CD MSE: 0.00471255
# GPA_DS MSE: 0.00085440
# [TEST] image No.15
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00493373
# DS MSE: 0.00095431
# GPA_CD MSE: 0.00492325
# GPA_DS MSE: 0.00096854
# [TEST] image No.16
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00502382
# DS MSE: 0.00098595
# GPA_CD MSE: 0.00501363
# GPA_DS MSE: 0.00100088
# [TEST] image No.17
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00547150
# DS MSE: 0.00107254
# GPA_CD MSE: 0.00546050
# GPA_DS MSE: 0.00108735
# [TEST] image No.18
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00587422
# DS MSE: 0.00113735
# GPA_CD MSE: 0.00586704
# GPA_DS MSE: 0.00115402
# [TEST] image No.19
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00611112
# DS MSE: 0.00119147
# GPA_CD MSE: 0.00610507
# GPA_DS MSE: 0.00120831
# [TEST] image No.20
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00640720
# DS MSE: 0.00125629
# GPA_CD MSE: 0.00640069
# GPA_DS MSE: 0.00127307
# [TEST] image No.21
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00659811
# DS MSE: 0.00130106
# GPA_CD MSE: 0.00658973
# GPA_DS MSE: 0.00131778
# [TEST] image No.22
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00699237
# DS MSE: 0.00165925
# GPA_CD MSE: 0.00702204
# GPA_DS MSE: 0.00171567
# [TEST] image No.23
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00735218
# DS MSE: 0.00173471
# GPA_CD MSE: 0.00737958
# GPA_DS MSE: 0.00179089
# [TEST] image No.24
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00747823
# DS MSE: 0.00176222
# GPA_CD MSE: 0.00750531
# GPA_DS MSE: 0.00181838
# [TEST] image No.25
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00760507
# DS MSE: 0.00183611
# GPA_CD MSE: 0.00762735
# GPA_DS MSE: 0.00188707
# [TEST] image No.26
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00804234
# DS MSE: 0.00190801
# GPA_CD MSE: 0.00806285
# GPA_DS MSE: 0.00195891
# [TEST] image No.27
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00848690
# DS MSE: 0.00198143
# GPA_CD MSE: 0.00850424
# GPA_DS MSE: 0.00203213
# [TEST] image No.28
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00896954
# DS MSE: 0.00206817
# GPA_CD MSE: 0.00898701
# GPA_DS MSE: 0.00211944
# [TEST] image No.29
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00946069
# DS MSE: 0.00252744
# GPA_CD MSE: 0.00948308
# GPA_DS MSE: 0.00258392
# [TEST] image No.30
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.00993151
# DS MSE: 0.00261518
# GPA_CD MSE: 0.00995205
# GPA_DS MSE: 0.00267145
# [TEST] image No.31
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01010457
# DS MSE: 0.00264996
# GPA_CD MSE: 0.01012439
# GPA_DS MSE: 0.00270615
# [TEST] image No.32
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01056664
# DS MSE: 0.00273746
# GPA_CD MSE: 0.01058490
# GPA_DS MSE: 0.00279357
# [TEST] image No.33
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01093121
# DS MSE: 0.00279653
# GPA_CD MSE: 0.01094767
# GPA_DS MSE: 0.00285259
# [TEST] image No.34
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01113787
# DS MSE: 0.00283536
# GPA_CD MSE: 0.01115217
# GPA_DS MSE: 0.00289242
# [TEST] image No.35
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01161618
# DS MSE: 0.00292300
# GPA_CD MSE: 0.01162911
# GPA_DS MSE: 0.00297999
# [TEST] image No.36
# [TEST] compute CD estimator
# [TEST] compute DS estimator
# [TEST] compute GPA-CD estimator
# [TEST] compute GPA-DS estimator
# Sample size N:500
# CD MSE: 0.01177112
# DS MSE: 0.00295527
# GPA_CD MSE: 0.01178429
# GPA_DS MSE: 0.00301230
# [TEST] image No.37
# [TEST] compute CD estimator

# %%
DS_mse
# Out:
# 0.002795512

# %%
def plot_density(s, tick_list, f_true, classic_density_tensor, DS_tensor):
    density_true = f_true[:, s[0], s[1]]
    density_hat = classic_density_tensor[:, s[0], s[1]]
    density_doubly_all = DS_tensor[:, s[0], s[1]]
    plt.scatter(tick_list, density_true, marker='o', s=2, label=f"True at ({s[0]}, {s[1]})")
    plt.scatter(tick_list, density_hat, marker='^', s=1, label=f"Classical")
    plt.scatter(tick_list, density_doubly_all, marker='+', s=1, label=f"Doubly")
    
    plt.legend(loc=3)
    plt.show()

# %%
print("Sample size N:", N)
s = (100, 200)
plot_density(s, tick_list, f_true, classic_density_tensor, DS_tensor)
# Out:
# Sample size N: 1000

# %%
tick_list.shape
# Out:
# (500,)

# %%
density_true = f_true[:, s[0], s[1]]
density_classic = classic_density_tensor[:, s[0], s[1]]
density_doubly = DS_tensor[:, s[0], s[1]]

density_stats = {"tick": tick_list,
                "density_true": density_true,
                 "density_classic": density_classic,
                 "density_doubly": density_doubly}
density_stats_csv = pd.DataFrame(density_stats)
density_stats_csv.to_csv(f'./density_stats_N={N}.csv')

# %%
mse_classic = MSE(tf.squeeze(test_true_density), test_classic_density_tensor)
mse_doubly = MSE(tf.squeeze(test_true_density), test_DS_tensor)
mse_GPA = MSE(tf.squeeze(test_true_density), GPA_density)

mse_classic_median = MSE_median(tf.squeeze(test_true_density), test_classic_density_tensor)
mse_doubly_median = MSE_median(tf.squeeze(test_true_density), test_DS_tensor)
mse_GPA_median = MSE_median(tf.squeeze(test_true_density), GPA_density)


print(f"Sample size N:{N}")
print(f"h:{bandwidth} and h*:", {round(bandwidth_star, 4)})
print(f"classic density MSE:", {round(mse_classic.numpy(), 4)}, f"\tclassic density MSE_mean:", {round(mse_classic_median, 6)}, f'\tTime:{round(classic_time, 4)}')
print(f"doubly density MSE:", {round(mse_doubly.numpy(), 4)}, f"\tdoubly density MSE_mean:", {round(mse_doubly_median, 6)}, f'\tTime:{round(doubly_time, 4)}')
print(f"GPA density MSE:", {round(mse_GPA.numpy(), 4)}, f"\tGPA density MSE_mean:", {round(mse_GPA_median, 6)}, f'\tTime:{round(GPA_time, 4)}')
# Out:
# Sample size N:1000
# h:0.02315827506916077 and h*: {0.0034}
# classic density MSE: {0.0042} 	classic density MSE_mean: {0.000216} 	Time:19.811
# doubly density MSE: {0.0467} 	doubly density MSE_mean: {4.2e-05} 	Time:19.8383
# GPA density MSE: {0.0468} 	GPA density MSE_mean: {4.1e-05} 	Time:0.0185
