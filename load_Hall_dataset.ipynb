# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np

mat = scipy.io.loadmat('/mnt/MineSafe-2024/dataset/Hall.mat')

# %%
data = mat['Data']
plt.imshow(data[:, :, 0])
p, q, d = data.shape

# %%
Data = np.zeros((d, p, q))

for k in range(d):
    raw_img = data[:, :, k]
    Data[k] = raw_img
